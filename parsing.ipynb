# %%
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$         INITIAL SETTINGS - НАЧАЛЬНЫЕ УСТАНОВКИ          $$$$$$$$$$$$$$$$$$$$$$$$$$$$

# %%
# Pandas
import pandas as pd
import numpy as np
import sys

# Подключаем библиотеку для парсинга сайтов !!!!!!!!!!!!!
import requests

# Подключаем библиотеку для поиска элементов кода на сайте !!!!!!!!!!!!!
from bs4 import BeautifulSoup

# %%
# 
# import sys

# %%
# Установка библиотеки для парсинга сайтов !!!!!!!!!!!!!
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\anaconda3\lib\site-packages (from requests) (2.10)

# %%
# Подключаем библиотеку для парсинга сайтов !!!!!!!!!!!!!
import requests

# %%
# Отправка запроса на сайт для получения кода:
res = requests.get('https://goodzel.ru/shop/')
res.text
# Out:
# '<!doctype html>\n<html lang="ru-RU" >\n\n<head>\n    <meta charset="UTF-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <link rel="preconnect" href="https://fonts.gstatic.com">\n    <link rel="stylesheet" type="text/css" href="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.css" />\n    <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@400;500;700&display=swap" rel="stylesheet">\n    <link rel="stylesheet" href="https://goodzel.ru/wp-content/themes/goodzel/css/style.css">\n\t<meta charset="UTF-8" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1" />\n\t<script id="yookassa-own-payment-methods-head">\nwindow.yookassaOwnPaymentMethods = [];\n</script>\n<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v23.0 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Каталог товаров - Интернет магазин профессиональной косметики Хороший</title>\n\t<meta name="description" content="Каталог профессиональных косметических средств и сопутствующих товаров в интернет магазине ХОРОШИЙ. Интернет магазин профессиональной косметики Хороший в Зеленограде приятно удивит Вас ценами и акциями. Тел. ☎+7 (499) 734-17-59" />\n\t<link rel="canonical" href="https://goodzel.ru/shop/" />\n\t<meta property="og:locale" content="ru_RU" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Каталог товаров - Интернет магазин профессиональной косметики Хороший" />\n\t<meta property="og:description" content="Каталог профессиональных косметических средств и сопутствующих товаров в интернет магазине ХОРОШИЙ. Интернет магазин профессиональной косметики Хороший в Зеленограде приятно удивит Вас ценами и акциями. Тел. ☎+7 (499) 734-17-59" />\n\t<meta property="og:url" content="https://goodzel.ru/shop/" />\n\t<meta property="og:site_name" content="Интернет магазин профессиональной косметики Хороший" />\n\t<meta property="article:modified_time" content="2021-03-03T12:48:40+00:00" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"WebPage","@id":"https://goodzel.ru/shop/","url":"https://goodzel.ru/shop/","name":"Каталог товаров - Интернет магазин профессиональной косметики Хороший","isPartOf":{"@id":"https://goodzel.ru/#website"},"datePublished":"2021-01-12T22:50:56+00:00","dateModified":"2021-03-03T12:48:40+00:00","description":"Каталог профессиональных косметических средств и сопутствующих товаров в интернет магазине ХОРОШИЙ. Интернет магазин профессиональной косметики Хороший в Зеленограде приятно удивит Вас ценами и акциями. Тел. ☎+7 (499) 734-17-59","breadcrumb":{"@id":"https://goodzel.ru/shop/#breadcrumb"},"inLanguage":"ru-RU","potentialAction":[{"@type":"ReadAction","target":["https://goodzel.ru/shop/"]}]},{"@type":"BreadcrumbList","@id":"https://goodzel.ru/shop/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Главная страница","item":"https://goodzel.ru/"},{"@type":"ListItem","position":2,"name":"Магазин"}]},{"@type":"WebSite","@id":"https://goodzel.ru/#website","url":"https://goodzel.ru/","name":"Интернет магазин профессиональной косметики Хороший","description":"","publisher":{"@id":"https://goodzel.ru/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://goodzel.ru/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"ru-RU"},{"@type":"Organization","@id":"https://goodzel.ru/#organization","name":"Интернет-магазин Хороший","url":"https://goodzel.ru/","logo":{"@type":"ImageObject","inLanguage":"ru-RU","@id":"https://goodzel.ru/#/schema/logo/image/","url":"https://goodzel.ru/wp-content/uploads/2021/03/logo.png","contentUrl":"https://goodzel.ru/wp-content/uploads/2021/03/l ...

# %%
# Искать нужные элементы в коде с помощью библиотеки:
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\anaconda3\lib\site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\anaconda3\lib\site-packages (from beautifulsoup4) (2.0.1)

# %%
# Подключаем библиотеку для поиска элементов кода на сайте !!!!!!!!!!!!!
from bs4 import BeautifulSoup

# %%
# Magic
soup = BeautifulSoup(res.text, 'html')
links = soup.find_all('a')
links
# Out:
# [<a class="header_top-messange" href="https://www.instagram.com/goodzel/" target="_blank">
#  <svg height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#  <style>
#                                          .cls-1 {
#                                              opacity: 0.5;
#                                          }
#                                      </style>
#  </defs>
#  <image class="cls-1" height="20" width="20" xlink:href="data:img/png;base64,..."/>
#  </svg>
#  </a>,
#  <a class="header_top-messange" href="https://vk.com/mag1824" target="_blank">
#  <svg height="12" viewbox="0 0 22 12" width="22" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#  <style>
#                                          .cls-1 {
#                                              opacity: 0.5;
#                                          }
#                                      </style>
#  </defs>
#  <image class="cls-1" height="12" width="22" xlink:href="data:img/png;base64,..."/>
#  </svg>
#  </a>,
#  <a class="header_top-messange" href="https://www.facebook.com/%D0%A5%D0%BE%D1%80%D0%BE%D1%88%D0%B8%D0%B9-%D0%BC%D0%B0%D0%B3%D0%B0%D0%B7%D0%B8%D0%BD-%D0%BF%D1%80%D0%BE%D1%84%D0%B5%D1%81%D1%81%D0%B8%D0%BE%D0%BD%D0%B0%D0%BB%D1%8C%D0%BD%D0%BE%D0%B9-%D0%BA%D0%BE%D1%81%D0%BC%D0%B5%D1%82%D0%B8%D0%BA%D0%B8-%D0%BF%D0%B0%D1%80%D0%B8%D0%BA%D0%BC%D0%B0%D1%85%D0%B5%D1%80%D1%81%D0%BA%D0%B8%D1%85-%D0%B8%D0%BD%D1%81%D1%82%D1%80%D1%83%D0%BC%D0%B5%D0%BD%D1%82%D0%BE%D0%B2-308277813200544/" target="_blank">
#  <svg height="18" viewbox="0 0 11 18" width="11" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#  <style>
#                                          .cls-1 {
#                                              opacity: 0.5;
#                                          }
#                                      </style>
#  </defs>
#  <image class="cls-1" height="18" width="11" xlink:href="data:img/png;base64,..."/>
#  </svg>
#  </a>,
#  <a class="header_top-number" href="tel:84997178196">+8 (499) 717-81-96</a>,
#  <a class="header_top-link" href="/news/">Новости для профессионалов</a>,
#  <a class="header_logo" href="/">
#  <img alt="" src="/wp-content/uploads/2021/01/logo.png" style="height: 137px;"/>
#  </a>,
#  <a aria-current="page" href="https://goodzel.ru/shop/">Каталог</a>,
#  <a href="https://goodzel.ru/news/">Блог</a>,
#  <a href="https://goodzel.ru/delivery_payment/">Доставка и оплата</a>,
#  <a href="https://goodzel.ru/faq/">Вопрос-ответ</a>,
#  <a href="https://goodzel.ru/contacts/">Контакты</a>,
#  <a class="basket-btn basket-btn_fixed-xs" href="/cart/">
#  <span class="basket-btn__label"><img alt="" src="/wp-content/uploads/card.png"/></span>
#  <span class="basket-btn__counter">0</span>
#  </a>,
#  <a class="header_top-number" href="tel:">+7 (499) 734-17-59</a>,
#  <a class="header_top-link" href="#">Новости для профессионалов</a>,
#  <a href="https://goodzel.ru" itemprop="item"><span itemprop="name">Главная</span></a>,
#  <a href="https://goodzel.ru/product-category/uncategorized/">Uncategorized</a>,
#  <a href="https://goodzel.ru/product-category/114/">АКСЕССУАРЫ ДЛЯ ВОЛОС</a>,
#  <a href="https://goodzel.ru/product-category/116/">БИЖУТЕРИЯ</a>,
#  <a href="https://goodzel.ru/product-category/eyebrows/">БРОВИ И РЕСНИЦЫ</a>,
#  <a href="https://goodzel.ru/product-category/depilation/">ДЕПИЛЯЦИЯ</a>,
#  <a href="https://goodzel.ru/product-category/mirror/">ЗЕРКАЛА</a>,
#  <a href="https://goodzel.ru/product-category/hair_cosmetics/">КОСМЕТИКА ДЛЯ ВОЛОС</a>,
#  <a href="https://goodzel.ru/product-category/beauty_supplies/">КОСМЕТИЧЕСКИЕ ПРИНАДЛЕЖНОСТИ</a>,
#  <a href="https://goodzel.ru/product-category/manicure_and_pedicure/">МАНИКЮР И ПЕДИКЮР</a>,
#  <a href="https://goodzel.ru/product-category/115/">НАКЛАДНЫЕ ВОЛОСЫ</a>,
#  <a href="https://goodzel.ru/product-category/disinfection/">ОДНОРАЗОВАЯ ПРОДУКЦИЯ И ДЕЗИНФЕКЦИЯ</a>,
#  <a href="https://goodzel.ru/product-category/hairdressing/">ПАРИКМАХЕРСКИЕ ИНСТРУМЕНТЫ И ПРИНАДЛЕЖНОСТИ</a>,
#  <a href="https://goodzel.ru/product-category/electrical/">ПРОФЕССИОНАЛЬНЫЕ ЭЛЕКТРОПРИБОРЫ</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/76076/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" fetchpriority="high" height="300" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-300x300.png" srcset="https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-300x300.png 300w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-1024x1024.png 1024w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-150x150.png 150w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-768x768.png 768w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-600x600.png 600w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-100x100.png 100w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527.png 1200w" style="width:100%;height:100%;max-width:1200px;" width="300"/><h2 class="woocommerce-loop-product__title">Пилка белая для искусственных ногтей 18см. 100/180</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>19<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_77704" aria-label="Добавить в корзину “Пилка белая для искусственных ногтей 18см. 100/180”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="77704" data-product_sku="ПБ100/180" data-quantity="1" href="?add-to-cart=77704" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/76077/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2024/01/76077_1704368801.2329-300x300.png" srcset="https://goodzel.ru/wp-content/uploads/2024/01/76077_1704368801.2329-300x300.png 300w, https://goodzel.ru/wp-content/uploads/2024/01/76077_1704368801.2329-1024x1024.png 1024w, https://goodzel.ru/wp-content/uploads/2024/01/76077_1704368801.2329-150x150.png 150w, https://goodzel.ru/wp-content/uploads/2024/01/76077_1704368801.2329-768x768.png 768w, https://goodzel.ru/wp-content/uploads/2024/01/76077_1704368801.2329-600x600.png 600w, https://goodzel.ru/wp-content/uploads/2024/01/76077_1704368801.2329-100x100.png 100w, https://goodzel.ru/wp-content/uploads/2024/01/76077_1704368801.2329.png 1200w" style="width:100%;height:100%;max-width:1200px;" width="300"/><h2 class="woocommerce-loop-product__title">Пилка белая для натуральных ногтей 18см. 180/240</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>19<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_77706" aria-label="Добавить в корзину “Пилка белая для натуральных ногтей 18см. 180/240”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="77706" data-product_sku="ПБ180/240" data-quantity="1" href="?add-to-cart=77706" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/76078/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2024/01/76078_1704369054.422-300x300.jpg" srcset="https://goodzel.ru/wp-content/uploads/2024/01/76078_1704369054.422-300x300.jpg 300w, https://goodzel.ru/wp-content/uploads/2024/01/76078_1704369054.422-1024x1024.jpg 1024w, https://goodzel.ru/wp-content/uploads/2024/01/76078_1704369054.422-150x150.jpg 150w, https://goodzel.ru/wp-content/uploads/2024/01/76078_1704369054.422-768x768.jpg 768w, https://goodzel.ru/wp-content/uploads/2024/01/76078_1704369054.422-1536x1536.jpg 1536w, https://goodzel.ru/wp-content/uploads/2024/01/76078_1704369054.422-1568x1568.jpg 1568w, https://goodzel.ru/wp-content/uploads/2024/01/76078_1704369054.422-600x600.jpg 600w, https://goodzel.ru/wp-content/uploads/2024/01/76078_1704369054.422-100x100.jpg 100w, https://goodzel.ru/wp-content/uploads/2024/01/76078_1704369054.422.jpg 1920w" style="width:100%;height:100%;max-width:1920px;" width="300"/><h2 class="woocommerce-loop-product__title">Пилка серая для искусственных ногтей 18см. 100/180</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>19<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_77708" aria-label="Добавить в корзину “Пилка серая для искусственных ногтей 18см. 100/180”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="77708" data-product_sku="ПС100/180" data-quantity="1" href="?add-to-cart=77708" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/76079/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2024/01/76079_1704369273.7427-300x300.jpg" srcset="https://goodzel.ru/wp-content/uploads/2024/01/76079_1704369273.7427-300x300.jpg 300w, https://goodzel.ru/wp-content/uploads/2024/01/76079_1704369273.7427-1024x1024.jpg 1024w, https://goodzel.ru/wp-content/uploads/2024/01/76079_1704369273.7427-150x150.jpg 150w, https://goodzel.ru/wp-content/uploads/2024/01/76079_1704369273.7427-768x768.jpg 768w, https://goodzel.ru/wp-content/uploads/2024/01/76079_1704369273.7427-1536x1536.jpg 1536w, https://goodzel.ru/wp-content/uploads/2024/01/76079_1704369273.7427-1568x1568.jpg 1568w, https://goodzel.ru/wp-content/uploads/2024/01/76079_1704369273.7427-600x600.jpg 600w, https://goodzel.ru/wp-content/uploads/2024/01/76079_1704369273.7427-100x100.jpg 100w, https://goodzel.ru/wp-content/uploads/2024/01/76079_1704369273.7427.jpg 1920w" style="width:100%;height:100%;max-width:1920px;" width="300"/><h2 class="woocommerce-loop-product__title">Пилка серая для натуральных ногтей 18см. 180/240</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>19<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_77710" aria-label="Добавить в корзину “Пилка серая для натуральных ногтей 18см. 180/240”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="77710" data-product_sku="ПС180/240" data-quantity="1" href="?add-to-cart=77710" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/34517/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="63" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2021/02/34517_1586178163.273-300x63.jpg" srcset="https://goodzel.ru/wp-content/uploads/2021/02/34517_1586178163.273-300x63.jpg 300w, https://goodzel.ru/wp-content/uploads/2021/02/34517_1586178163.273-150x31.jpg 150w, https://goodzel.ru/wp-content/uploads/2021/02/34517_1586178163.273-768x160.jpg 768w, https://goodzel.ru/wp-content/uploads/2021/02/34517_1586178163.273-600x125.jpg 600w, https://goodzel.ru/wp-content/uploads/2021/02/34517_1586178163.273.jpg 800w" style="width:100%;height:20.88%;max-width:800px;" width="300"/><h2 class="woocommerce-loop-product__title">Хомуты на коклюшки (1 шт)</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>19<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_32009" aria-label="Добавить в корзину “Хомуты на коклюшки (1 шт)”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="32009" data-product_sku="R-SRL-50" data-quantity="1" href="?add-to-cart=32009" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/33123/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2021/02/2773657-300x300.jpg" srcset="https://goodzel.ru/wp-content/uploads/2021/02/2773657-300x300.jpg 300w, https://goodzel.ru/wp-content/uploads/2021/02/2773657-150x150.jpg 150w, https://goodzel.ru/wp-content/uploads/2021/02/2773657-100x100.jpg 100w, https://goodzel.ru/wp-content/uploads/2021/02/2773657.jpg 440w" style="width:100%;height:100%;max-width:440px;" width="300"/><h2 class="woocommerce-loop-product__title">ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 6%, 60мл</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>119<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_30360" aria-label="Добавить в корзину “ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 6%, 60мл”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="30360" data-product_sku="P/O6/60" data-quantity="1" href="?add-to-cart=30360" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/76134/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2024/01/76134_1704469715.4488-300x300.jpg" srcset="https://goodzel.ru/wp-content/uploads/2024/01/76134_1704469715.4488-300x300.jpg 300w, https://goodzel.ru/wp-content/uploads/2024/01/76134_1704469715.4488-150x150.jpg 150w, https://goodzel.ru/wp-content/uploads/2024/01/76134_1704469715.4488-768x768.jpg 768w, https://goodzel.ru/wp-content/uploads/2024/01/76134_1704469715.4488-600x600.jpg 600w, https://goodzel.ru/wp-content/uploads/2024/01/76134_1704469715.4488-100x100.jpg 100w, https://goodzel.ru/wp-content/uploads/2024/01/76134_1704469715.4488.jpg 800w" style="width:100%;height:100%;max-width:800px;" width="300"/><h2 class="woocommerce-loop-product__title">Профессиональная пилка для искусственных ногтей 100/180 «NailSunShine»</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>19<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_77820" aria-label='Добавить в корзину “Профессиональная пилка для искусственных ногтей 100/180 "NailSunShine"”' class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="77820" data-product_sku="ППР100/180" data-quantity="1" href="?add-to-cart=77820" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/76411/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2024/03/76411_1707918785.2006-300x300.jpg" srcset="https://goodzel.ru/wp-content/uploads/2024/03/76411_1707918785.2006-300x300.jpg 300w, https://goodzel.ru/wp-content/uploads/2024/03/76411_1707918785.2006-150x150.jpg 150w, https://goodzel.ru/wp-content/uploads/2024/03/76411_1707918785.2006-768x768.jpg 768w, https://goodzel.ru/wp-content/uploads/2024/03/76411_1707918785.2006-600x600.jpg 600w, https://goodzel.ru/wp-content/uploads/2024/03/76411_1707918785.2006-100x100.jpg 100w, https://goodzel.ru/wp-content/uploads/2024/03/76411_1707918785.2006.jpg 800w" style="width:100%;height:100%;max-width:800px;" width="300"/><h2 class="woocommerce-loop-product__title">Шапочка для душа</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>69<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_78909" aria-label="Добавить в корзину “Шапочка для душа”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="78909" data-product_sku="Ш69" data-quantity="1" href="?add-to-cart=78909" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/64969/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="200" loading="lazy" sizes="(max-width: 150px) 100vw, 150px" src="https://goodzel.ru/wp-content/uploads/2021/02/64969_1587119889.1725.jpg" srcset="https://goodzel.ru/wp-content/uploads/2021/02/64969_1587119889.1725.jpg 150w, https://goodzel.ru/wp-content/uploads/2021/02/64969_1587119889.1725-113x150.jpg 113w" style="width:100%;height:133.33%;max-width:150px;" width="150"/><h2 class="woocommerce-loop-product__title">Дизайн-блестки ассорти зеркальные</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>89<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_50215" aria-label="Добавить в корзину “Дизайн-блестки ассорти зеркальные”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="50215" data-product_sku="AN1094" data-quantity="1" href="?add-to-cart=50215" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/76135/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2024/01/76135_1704470142.2247-300x300.jpg" srcset="https://goodzel.ru/wp-content/uploads/2024/01/76135_1704470142.2247-300x300.jpg 300w, https://goodzel.ru/wp-content/uploads/2024/01/76135_1704470142.2247-150x150.jpg 150w, https://goodzel.ru/wp-content/uploads/2024/01/76135_1704470142.2247-600x600.jpg 600w, https://goodzel.ru/wp-content/uploads/2024/01/76135_1704470142.2247-100x100.jpg 100w, https://goodzel.ru/wp-content/uploads/2024/01/76135_1704470142.2247.jpg 750w" style="width:100%;height:100%;max-width:750px;" width="300"/><h2 class="woocommerce-loop-product__title">Профессиональная пилка для натуральных ногтей 180/240 «NailSunShine»</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>19<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_77822" aria-label='Добавить в корзину “Профессиональная пилка для натуральных ногтей 180/240 "NailSunShine"”' class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="77822" data-product_sku="ППР180/240" data-quantity="1" href="?add-to-cart=77822" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/37655/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2021/02/37655_1610227707.6167-300x300.jpg" srcset="https://goodzel.ru/wp-content/uploads/2021/02/37655_1610227707.6167-300x300.jpg 300w, https://goodzel.ru/wp-content/uploads/2021/02/37655_1610227707.6167-150x150.jpg 150w, https://goodzel.ru/wp-content/uploads/2021/02/37655_1610227707.6167-100x100.jpg 100w, https://goodzel.ru/wp-content/uploads/2021/02/37655_1610227707.6167.jpg 600w" style="width:100%;height:100%;max-width:600px;" width="300"/><h2 class="woocommerce-loop-product__title">Терка педикюрная деревянная 2-х ст. CAMILLEN 60</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>159<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_33501" aria-label="Добавить в корзину “Терка педикюрная деревянная 2-х ст. CAMILLEN 60”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="33501" data-product_sku="8260" data-quantity="1" href="?add-to-cart=33501" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/74091/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2022/06/74091_1654597402.5899-300x300.jpg" srcset="https://goodzel.ru/wp-content/uploads/2022/06/74091_1654597402.5899-300x300.jpg 300w, https://goodzel.ru/wp-content/uploads/2022/06/74091_1654597402.5899-150x150.jpg 150w, https://goodzel.ru/wp-content/uploads/2022/06/74091_1654597402.5899-100x100.jpg 100w, https://goodzel.ru/wp-content/uploads/2022/06/74091_1654597402.5899.jpg 473w" style="width:100%;height:100%;max-width:473px;" width="300"/><h2 class="woocommerce-loop-product__title">Фольга для парикмахерская Standart 12см х 100м 12мкм</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>519<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_73429" aria-label="Добавить в корзину “Фольга для парикмахерская Standart 12см х 100м 12мкм”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="73429" data-product_sku="АП1221500" data-quantity="1" href="?add-to-cart=73429" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/44497/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2024/04/44497_1588775762.2777-300x300.png" srcset="https://goodzel.ru/wp-content/uploads/2024/04/44497_1588775762.2777-300x300.png 300w, https://goodzel.ru/wp-content/uploads/2024/04/44497_1588775762.2777-150x150.png 150w, https://goodzel.ru/wp-content/uploads/2024/04/44497_1588775762.2777-768x768.png 768w, https://goodzel.ru/wp-content/uploads/2024/04/44497_1588775762.2777-600x600.png 600w, https://goodzel.ru/wp-content/uploads/2024/04/44497_1588775762.2777-100x100.png 100w, https://goodzel.ru/wp-content/uploads/2024/04/44497_1588775762.2777.png 1000w" style="width:100%;height:100%;max-width:1000px;" width="300"/><h2 class="woocommerce-loop-product__title">Тапочки пенополиэтилен 5мм.голубые White line 2 шт.</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>29<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_79661" aria-label="Добавить в корзину “Тапочки пенополиэтилен 5мм.голубые White line 2 шт.”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="79661" data-product_sku="10369" data-quantity="1" href="?add-to-cart=79661" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/74089/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2022/06/74089_1654596691.5049-300x300.jpg" srcset="https://goodzel.ru/wp-content/uploads/2022/06/74089_1654596691.5049-300x300.jpg 300w, https://goodzel.ru/wp-content/uploads/2022/06/74089_1654596691.5049-150x150.jpg 150w, https://goodzel.ru/wp-content/uploads/2022/06/74089_1654596691.5049-100x100.jpg 100w, https://goodzel.ru/wp-content/uploads/2022/06/74089_1654596691.5049.jpg 473w" style="width:100%;height:100%;max-width:473px;" width="300"/><h2 class="woocommerce-loop-product__title">Фольга для парикмахерская Standart 12см х25м 12мкм</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>159<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_73425" aria-label="Добавить в корзину “Фольга для парикмахерская Standart 12см х25м 12мкм”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="73425" data-product_sku="АП1221155" data-quantity="1" href="?add-to-cart=73425" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/70606/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="206" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2021/02/70606_1608822735.1984-300x206.jpg" srcset="https://goodzel.ru/wp-content/uploads/2021/02/70606_1608822735.1984-300x206.jpg 300w, https://goodzel.ru/wp-content/uploads/2021/02/70606_1608822735.1984-150x103.jpg 150w, https://goodzel.ru/wp-content/uploads/2021/02/70606_1608822735.1984-768x527.jpg 768w, https://goodzel.ru/wp-content/uploads/2021/02/70606_1608822735.1984-600x411.jpg 600w, https://goodzel.ru/wp-content/uploads/2021/02/70606_1608822735.1984.jpg 900w" style="width:100%;height:68.56%;max-width:900px;" width="300"/><h2 class="woocommerce-loop-product__title">Нитриловые перчатки неопудренные, текстурированные, нестерильные «Nitrile Hands Clean» Kapous, фиолетовые, 2 шт., XS</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>19<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_60493" aria-label="Добавить в корзину “Нитриловые перчатки неопудренные, текстурированные, нестерильные «Nitrile Hands Clean» Kapous, фиолетовые, 2 шт., XS”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="60493" data-product_sku="2238" data-quantity="1" href="?add-to-cart=60493" rel="nofollow">В корзину</a>,
#  <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/33124/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" height="300" loading="lazy" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2021/02/2728291-300x300.jpg" srcset="https://goodzel.ru/wp-content/uploads/2021/02/2728291-300x300.jpg 300w, https://goodzel.ru/wp-content/uploads/2021/02/2728291-150x150.jpg 150w, https://goodzel.ru/wp-content/uploads/2021/02/2728291-100x100.jpg 100w, https://goodzel.ru/wp-content/uploads/2021/02/2728291.jpg 440w" style="width:100%;height:100%;max-width:440px;" width="300"/><h2 class="woocommerce-loop-product__title">ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 9%, 60мл</h2>
#  <span class="price"><span class="woocommerce-Price-amount amount"><bdi>119<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
#  </a>,
#  <a aria-describedby="woocommerce_loop_add_to_cart_link_describedby_30362" aria-label="Добавить в корзину “ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 9%, 60мл”" class="button product_type_simple add_to_cart_button ajax_add_to_cart" data-product_id="30362" data-product_sku="P/O9/60" data-quantity="1" href="?add-to-cart=30362" rel="nofollow">В корзину</a>,
#  <a class="page-numbers" href="/shop/?product-page=2">2</a>,
#  <a class="page-numbers" href="/shop/?product-page=3">3</a>,
#  <a class="page-numbers" href="/shop/?product-page=4">4</a>,
#  <a class="page-numbers" href="/shop/?product-page=741">741</a>,
#  <a class="page-numbers" href="/shop/?product-page=742">742</a>,
#  <a class="page-numbers" href="/shop/?product-page=743">743</a>,
#  <a class="next page-numbers" href="/shop/?product-page=2">→</a>,
#  <a class="footer_nav-link" href="/shop-info/">О магазине</a>,
#  <a class="footer_nav-link" href="/news/">Блог</a>,
#  <a class="footer_nav-link" href="/sale/">Акции</a>,
#  <a class="footer_nav-link" href="/faq/">Помощь</a>,
#  <a class="footer_nav-link" href="/delivery_payment/">Условия доставки</a>,
#  <a class="footer_nav-link" href="/delivery_payment/?d=true">Возврат</a>,
#  <a class="footer_nav-number" href="tel:+74997178196">+7 (499) 717-81-96</a>,
#  <a class="footer_nav-number" href="tel:+74997341759">+7 (499) 734-17-59</a>,
#  <a class="footer_nav-number" href="tel:+79168080355">+7(916)808-03-55</a>,
#  <a class="footer_nav-mail" href="">info@goodzel.ru</a>,
#  <a href="/privacy-policy/" style="color: white;">Политика конфиденциальности</a>]

# %%
# Чтобы извлечь из ссылки текст:
[x.text for x in links]
# Out:
# ['\n\n\n\n\n\n\n',
#  '\n\n\n\n\n\n\n',
#  '\n\n\n\n\n\n\n',
#  '+8 (499) 717-81-96',
#  'Новости для профессионалов',
#  '\n\n',
#  'Каталог',
#  'Блог',
#  'Доставка и оплата',
#  'Вопрос-ответ',
#  'Контакты',
#  '\n\n0\n',
#  '+7 (499) 734-17-59',
#  'Новости для профессионалов',
#  'Главная',
#  'Uncategorized',
#  'АКСЕССУАРЫ ДЛЯ ВОЛОС',
#  'БИЖУТЕРИЯ',
#  'БРОВИ И РЕСНИЦЫ',
#  'ДЕПИЛЯЦИЯ',
#  'ЗЕРКАЛА',
#  'КОСМЕТИКА ДЛЯ ВОЛОС',
#  'КОСМЕТИЧЕСКИЕ ПРИНАДЛЕЖНОСТИ',
#  'МАНИКЮР И ПЕДИКЮР',
#  'НАКЛАДНЫЕ ВОЛОСЫ',
#  'ОДНОРАЗОВАЯ ПРОДУКЦИЯ И ДЕЗИНФЕКЦИЯ',
#  'ПАРИКМАХЕРСКИЕ ИНСТРУМЕНТЫ И ПРИНАДЛЕЖНОСТИ',
#  'ПРОФЕССИОНАЛЬНЫЕ ЭЛЕКТРОПРИБОРЫ',
#  'Пилка белая для искусственных ногтей 18см. 100/180\n19₽\n',
#  'В корзину',
#  'Пилка белая для натуральных ногтей 18см. 180/240\n19₽\n',
#  'В корзину',
#  'Пилка серая для искусственных ногтей 18см. 100/180\n19₽\n',
#  'В корзину',
#  'Пилка серая для натуральных ногтей 18см. 180/240\n19₽\n',
#  'В корзину',
#  'Хомуты на коклюшки (1 шт)\n19₽\n',
#  'В корзину',
#  'ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 6%, 60мл\n119₽\n',
#  'В корзину',
#  'Профессиональная пилка для искусственных ногтей 100/180 «NailSunShine»\n19₽\n',
#  'В корзину',
#  'Шапочка для душа\n69₽\n',
#  'В корзину',
#  'Дизайн-блестки ассорти зеркальные\n89₽\n',
#  'В корзину',
#  'Профессиональная пилка для натуральных ногтей 180/240 «NailSunShine»\n19₽\n',
#  'В корзину',
#  'Терка педикюрная деревянная 2-х ст. CAMILLEN 60\n159₽\n',
#  'В корзину',
#  'Фольга для парикмахерская Standart 12см х 100м 12мкм\n519₽\n',
#  'В корзину',
#  'Тапочки пенополиэтилен 5мм.голубые White line 2 шт.\n29₽\n',
#  'В корзину',
#  'Фольга для парикмахерская Standart 12см х25м 12мкм\n159₽\n',
#  'В корзину',
#  'Нитриловые перчатки неопудренные, текстурированные, нестерильные «Nitrile Hands Clean» Kapous, фиолетовые, 2 шт., XS\n19₽\n',
#  'В корзину',
#  'ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 9%, 60мл\n119₽\n',
#  'В корзину',
#  '2',
#  '3',
#  '4',
#  '741',
#  '742',
#  '743',
#  '→',
#  'О магазине',
#  'Блог',
#  'Акции',
#  'Помощь',
#  'Условия доставки',
#  'Возврат',
#  '+7 (499) 717-81-96',
#  '+7 (499) 734-17-59',
#  '+7(916)808-03-55',
#  'info@goodzel.ru',
#  'Политика конфиденциальности']

# %%
# Magic_2 - Извлекаем инфу с описанием товаров
# soup.find_all('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')

# Оставляем только текстовую информацию
[t.text for t in soup.find_all('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')]
# links[0]
# Out:
# ['Пилка белая для искусственных ногтей 18см. 100/180\n19₽\n',
#  'Пилка белая для натуральных ногтей 18см. 180/240\n19₽\n',
#  'Пилка серая для искусственных ногтей 18см. 100/180\n19₽\n',
#  'Пилка серая для натуральных ногтей 18см. 180/240\n19₽\n',
#  'Хомуты на коклюшки (1 шт)\n19₽\n',
#  'ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 6%, 60мл\n119₽\n',
#  'Профессиональная пилка для искусственных ногтей 100/180 «NailSunShine»\n19₽\n',
#  'Шапочка для душа\n69₽\n',
#  'Дизайн-блестки ассорти зеркальные\n89₽\n',
#  'Профессиональная пилка для натуральных ногтей 180/240 «NailSunShine»\n19₽\n',
#  'Терка педикюрная деревянная 2-х ст. CAMILLEN 60\n159₽\n',
#  'Фольга для парикмахерская Standart 12см х 100м 12мкм\n519₽\n',
#  'Тапочки пенополиэтилен 5мм.голубые White line 2 шт.\n29₽\n',
#  'Фольга для парикмахерская Standart 12см х25м 12мкм\n159₽\n',
#  'Нитриловые перчатки неопудренные, текстурированные, нестерильные «Nitrile Hands Clean» Kapous, фиолетовые, 2 шт., XS\n19₽\n',
#  'ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 9%, 60мл\n119₽\n']

# %%
# Избавляемся от всего лишнего
# [t.text.strip() for t in soup.find_all('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')]

# Сохраняем в переменную для дальнейшего использования наименования товаров
titles = [t.text.strip().split('\n')[0] for t in soup.find_all('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')]
titles
# Out:
# ['Пилка белая для искусственных ногтей 18см. 100/180',
#  'Пилка белая для натуральных ногтей 18см. 180/240',
#  'Пилка серая для искусственных ногтей 18см. 100/180',
#  'Пилка серая для натуральных ногтей 18см. 180/240',
#  'Хомуты на коклюшки (1 шт)',
#  'ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 6%, 60мл',
#  'Профессиональная пилка для искусственных ногтей 100/180 «NailSunShine»',
#  'Шапочка для душа',
#  'Дизайн-блестки ассорти зеркальные',
#  'Профессиональная пилка для натуральных ногтей 180/240 «NailSunShine»',
#  'Терка педикюрная деревянная 2-х ст. CAMILLEN 60',
#  'Фольга для парикмахерская Standart 12см х 100м 12мкм',
#  'Тапочки пенополиэтилен 5мм.голубые White line 2 шт.',
#  'Фольга для парикмахерская Standart 12см х25м 12мкм',
#  'Нитриловые перчатки неопудренные, текстурированные, нестерильные «Nitrile Hands Clean» Kapous, фиолетовые, 2 шт., XS',
#  'ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 9%, 60мл']

# %%
# Сохраняем в переменную для дальнейшего использования наименования товаров
prices = [t.text.strip().split('\n')[1].replace('₽','') for t in soup.find_all('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')]
prices
# Out:
# ['19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '119',
#  '19',
#  '69',
#  '89',
#  '19',
#  '159',
#  '519',
#  '29',
#  '159',
#  '19',
#  '119']

# %%
# Альтернативный способ поиска элементов:
elements = soup.find_all('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')

# Посмотрим на первый элемент
elements[0]
# Out:
# <a class="woocommerce-LoopProduct-link woocommerce-loop-product__link" href="https://goodzel.ru/product/76076/"><img alt="" class="attachment-medium size-medium wp-post-image" decoding="async" fetchpriority="high" height="300" sizes="(max-width: 300px) 100vw, 300px" src="https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-300x300.png" srcset="https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-300x300.png 300w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-1024x1024.png 1024w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-150x150.png 150w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-768x768.png 768w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-600x600.png 600w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527-100x100.png 100w, https://goodzel.ru/wp-content/uploads/2024/01/76076_1704368818.6527.png 1200w" style="width:100%;height:100%;max-width:1200px;" width="300"/><h2 class="woocommerce-loop-product__title">Пилка белая для искусственных ногтей 18см. 100/180</h2>
# <span class="price"><span class="woocommerce-Price-amount amount"><bdi>19<span class="woocommerce-Price-currencySymbol">₽</span></bdi></span></span>
# </a>

# %%
# Выделяем из одного элемента всю информацию по отдельности, и преобразуем её в объект:
elements = soup.find_all('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')
data = []

for e in elements:
    data.append({
        'title': e.text.strip().split('\n')[0],
        'price': e.text.strip().split('\n')[1].replace('₽',''),
    })
    
data
# Out:
# [{'title': 'Пилка белая для искусственных ногтей 18см. 100/180',
#   'price': '19'},
#  {'title': 'Пилка белая для натуральных ногтей 18см. 180/240', 'price': '19'},
#  {'title': 'Пилка серая для искусственных ногтей 18см. 100/180',
#   'price': '19'},
#  {'title': 'Пилка серая для натуральных ногтей 18см. 180/240', 'price': '19'},
#  {'title': 'Хомуты на коклюшки (1 шт)', 'price': '19'},
#  {'title': 'ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 6%, 60мл',
#   'price': '119'},
#  {'title': 'Профессиональная пилка для искусственных ногтей 100/180 «NailSunShine»',
#   'price': '19'},
#  {'title': 'Шапочка для душа', 'price': '69'},
#  {'title': 'Дизайн-блестки ассорти зеркальные', 'price': '89'},
#  {'title': 'Профессиональная пилка для натуральных ногтей 180/240 «NailSunShine»',
#   'price': '19'},
#  {'title': 'Терка педикюрная деревянная 2-х ст. CAMILLEN 60', 'price': '159'},
#  {'title': 'Фольга для парикмахерская Standart 12см х 100м 12мкм',
#   'price': '519'},
#  {'title': 'Тапочки пенополиэтилен 5мм.голубые White line 2 шт.',
#   'price': '29'},
#  {'title': 'Фольга для парикмахерская Standart 12см х25м 12мкм',
#   'price': '159'},
#  {'title': 'Нитриловые перчатки неопудренные, текстурированные, нестерильные «Nitrile Hands Clean» Kapous, фиолетовые, 2 шт., XS',
#   'price': '19'},
#  {'title': 'ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 9%, 60мл',
#   'price': '119'}]

# %%
# Подключаем Pandas и преобразуем объект в датафрейм:
df = pd.DataFrame(data)
df

# Мы распарсили одну страничку каталога !!!!!!!!
# Out:
#                                                 title price
# 0   Пилка белая для искусственных ногтей 18см. 100...    19
# 1    Пилка белая для натуральных ногтей 18см. 180/240    19
# 2   Пилка серая для искусственных ногтей 18см. 100...    19
# 3    Пилка серая для натуральных ногтей 18см. 180/240    19
# 4                           Хомуты на коклюшки (1 шт)    19
# 5   ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 6%...   119
# 6   Профессиональная пилка для искусственных ногте...    19
# 7                                    Шапочка для душа    69
# 8                   Дизайн-блестки ассорти зеркальные    89
# 9   Профессиональная пилка для натуральных ногтей ...    19
# 10    Терка педикюрная деревянная 2-х ст. CAMILLEN 60   159
# 11  Фольга для парикмахерская Standart 12см х 100м...   519
# 12  Тапочки пенополиэтилен 5мм.голубые White line ...    29
# 13  Фольга для парикмахерская Standart 12см х25м 1...   159
# 14  Нитриловые перчатки неопудренные, текстурирова...    19
# 15  ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 9%...   119

# %%
# Поменяем переменную RES на:
# Отправка запроса на сайт для получения кода:
data = []
page = 1

res = requests.get(f'https://goodzel.ru/shop/?product-page={page}')
soup = BeautifulSoup(res.text, 'html')

elements = soup.find_all('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')

for e in elements:
    data.append({
        'title': e.text.strip().split('\n')[0],
        'price': e.text.strip().split('\n')[1].replace('₽',''),
    })
    
df = pd.DataFrame(data)
df
# Out:
#                                                 title price
# 0   Пилка белая для искусственных ногтей 18см. 100...    19
# 1    Пилка белая для натуральных ногтей 18см. 180/240    19
# 2   Пилка серая для искусственных ногтей 18см. 100...    19
# 3    Пилка серая для натуральных ногтей 18см. 180/240    19
# 4                           Хомуты на коклюшки (1 шт)    19
# 5   ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 6%...   119
# 6   Профессиональная пилка для искусственных ногте...    19
# 7                                    Шапочка для душа    69
# 8                   Дизайн-блестки ассорти зеркальные    89
# 9   Профессиональная пилка для натуральных ногтей ...    19
# 10    Терка педикюрная деревянная 2-х ст. CAMILLEN 60   159
# 11  Фольга для парикмахерская Standart 12см х 100м...   519
# 12  Тапочки пенополиэтилен 5мм.голубые White line ...    29
# 13  Фольга для парикмахерская Standart 12см х25м 1...   159
# 14  Нитриловые перчатки неопудренные, текстурирова...    19
# 15  ESTEL PROFESSIONNEL PRINCESS ESSEX Оксигент 9%...   119

# %%
# Теперь надо распарсить все страницы каталога:
# Отправка запроса на сайт для получения кода:

data = []
page = 1
max_page = 1

while page <= max_page:
    res = requests.get(f'https://goodzel.ru/shop/?product-page={page}')
    soup = BeautifulSoup(res.text, 'html')

    elements = soup.find_all('a', class_='woocommerce-LoopProduct-link woocommerce-loop-product__link')

    for e in elements:
        data.append({
            'title': e.text.strip().split('\n')[0],
            'price': e.text.strip().split('\n')[1].replace('₽',''),
        })

# Усложняем код из-за появления в нумерации страниц знаков "..."        
        
    pagination = soup.find('a', class_='page-numbers')
#     pagination = soup.find('nav', class_='woocommerce-pagination')
    pages = [int(p) for p in pagination.text.strip()]
#     pages = [int(p.text.strip()) for p in pagination.find_all('a', class_='page-numbers')]
    print(pages)
    int_pages = []
    
    for p in pages:
        try:
            n = int(p)
            int_pages.append(n)
        except:
            continue
            
    print(int_pages)
    max_page = max(int_pages)
    page += 1
    print(page, max_page)

#     df = pd.DataFrame(data)
#     df
# Out:
# [2]
# [2]
# 2 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-0af01efd1400> in <module>
#      22     pagination = soup.find('a', class_='page-numbers')
#      23 #     pagination = soup.find('nav', class_='woocommerce-pagination')
# ---> 24     pages = [int(p) for p in pagination.text.strip()]
#      25 #     pages = [int(p.text.strip()) for p in pagination.find_all('a', class_='page-numbers')]
#      26     print(pages)
#
# <ipython-input-104-0af01efd1400> in <listcomp>(.0)
#      22     pagination = soup.find('a', class_='page-numbers')
#      23 #     pagination = soup.find('nav', class_='woocommerce-pagination')
# ---> 24     pages = [int(p) for p in pagination.text.strip()]
#      25 #     pages = [int(p.text.strip()) for p in pagination.find_all('a', class_='page-numbers')]
#      26     print(pages)
#
# ValueError: invalid literal for int() with base 10: '←'

# %%
# Отправка запроса на сайт для получения кода:
res1 = requests.get('https://salonak.ru/katalog-tovarov/')
res1.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n\t<meta name="viewport" content="width=device-width">\r\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r<meta http-equiv="Content-Language" content="ru" />\r<meta name="author" content="ur66.ru" />\r<meta name="format-detection" content="telephone=no" />\r<meta name="referrer" content="strict-origin-when-cross-origin" />\r<title>Профессиональная косметика для волос и ногтей - salonak.ru - Екатеринбург</title>\r<meta name="description" content="salonak.ru - Екатеринбург - Профессиональная косметика для волос и ногтей" />\r<base href="https://salonak.ru" />\r<link rel="shortcut icon" href="/favicon.png" type="image/png" />\r\r<link href="//s1.uralcms.com/uss-css/uss_style_8.5.0.min.css" rel="stylesheet" type="text/css" />\r<link href="https://salonak.ru/css/style.css?d=1716738900" rel="stylesheet" type="text/css" />\r<script src="//s1.uralcms.com/uss-js/jquery-1.9.1.min.js" type="text/javascript"></script>\r<script src="//s1.uralcms.com/uss-js/jquery.formstyler.min.js" type="text/javascript"></script>\r<link rel="preload" href="//s1.uralcms.com/uss-js/jquery.form.min.js" as="script"/>\r<link rel="preload" href="//s1.uralcms.com/uss-js/jquery.autocomplete.min.js" as="script"/>\r<link rel="preload" href="//s1.uralcms.com/uss-js/uss-script-8.5.0.min.js" as="script"/>\r<!-- Google tag (gtag.js) -->\r\n<script async src="https://www.googletagmanager.com/gtag/js?id=G-V9WQKML7DX"></script>\r\n<script>\r\n  window.dataLayer = window.dataLayer || [];\r\n  function gtag(){dataLayer.push(arguments);}\r\n  gtag(\'js\', new Date());\r\n\r\n  gtag(\'config\', \'G-V9WQKML7DX\');\r\n</script>\r\n<meta name="google-site-verification" content="z2qKGNTfHKZKIv2wiqILo6BnMsPFRTcmk-r2EdklT9g" />\r\t<script src="//s1.uralcms.com/uss-js/uss-extra.js"></script>\r\n</head>\r\n<body class="colorStyle1  singlepage" template_name="K8">\r\n\t<div id="wrap">\r\n\t\t<div class="modal feedback-form">\r\n\t\t\t<div class="h3">Заказать звонок</div><script type="text/javascript" src="//s1.uralcms.com/uss-js/imask.min.js"></script><script type="text/javascript" src="//s1.uralcms.com/uss-js/jquery.cookie.js"></script><div class="fc_form_tml">\r\n\t<form action="https://salonak.ru/zakazat-zvonok/" method="post" class="fc_form  validate form_block ajax_send form_styler id77132 fc_form_10137849"  accept-charset="utf-8" data-id="10137849"><a name="FormConstructorForm"></a><div class="uss_error_form" style="display: none;"></div><div class="group group_10137849_1 label_position_top end"><div class="fc_item fc_text sector_required fc_item_10137849_1_2" id="fc_item_1_2_block_id"><div class="fc_label_wrap"><div class="label_under_hint"><label for="fc_field_1_2_block_id" class=" sector_title">Ваше Имя<span class="not_empty_field_mark">*</span></label></div><div class="elem_item"><input type="text" class="fc_field_10137849_1_2 styler"  name="1_2" id="fc_field_1_2_block_id" value=""/></div></div></div><div class="fc_item fc_text sector_required fc_item_10137849_1_3" id="fc_item_1_3_block_id"><div class="fc_label_wrap"><div class="label_under_hint"><label for="fc_field_1_3_block_id" class=" sector_title">Телефон<span class="not_empty_field_mark">*</span></label></div><div class="elem_item"><input type="text" class="fc_field_10137849_1_3 styler"  name="1_3" id="fc_field_1_3_block_id" value=""/></div></div></div><div class="fc_item fc_textarea fc_item_10137849_1_7" id="fc_item_1_7_block_id"><div class="label_under_hint"><label for="fc_field_1_7_block_id" class=" sector_title label_textarea">Комментарий (не обязательно)</label></div><div class="elem_item"><textarea class="fc_field_10137849_1_7 styler"  name="1_7" id="fc_field_1_7_block_id"></textarea></div></div><div class="fc_item fc_checkbox sector_required fc_item_10137849_1_6 fc_checkbox_one" id="fc_item_1_6_block_id"><div class="elem_item one"><input class="fc_field_10137849_1_6 styler"  type="checkbox"  name="1_6" id="fc_field_1_6_block_id" value="on" ...

# %%
# Magic
soup1 = BeautifulSoup(res1.text, 'html')
links1 = soup1.find_all('div')
links1
# Out:
# [<div id="wrap">
#  <div class="modal feedback-form">
#  <div class="h3">Заказать звонок</div><script src="//s1.uralcms.com/uss-js/imask.min.js" type="text/javascript"></script><script src="//s1.uralcms.com/uss-js/jquery.cookie.js" type="text/javascript"></script><div class="fc_form_tml">
#  <form accept-charset="utf-8" action="https://salonak.ru/zakazat-zvonok/" class="fc_form validate form_block ajax_send form_styler id77132 fc_form_10137849" data-id="10137849" method="post"><a name="FormConstructorForm"></a><div class="uss_error_form" style="display: none;"></div><div class="group group_10137849_1 label_position_top end"><div class="fc_item fc_text sector_required fc_item_10137849_1_2" id="fc_item_1_2_block_id"><div class="fc_label_wrap"><div class="label_under_hint"><label class="sector_title" for="fc_field_1_2_block_id">Ваше Имя<span class="not_empty_field_mark">*</span></label></div><div class="elem_item"><input class="fc_field_10137849_1_2 styler" id="fc_field_1_2_block_id" name="1_2" type="text" value=""/></div></div></div><div class="fc_item fc_text sector_required fc_item_10137849_1_3" id="fc_item_1_3_block_id"><div class="fc_label_wrap"><div class="label_under_hint"><label class="sector_title" for="fc_field_1_3_block_id">Телефон<span class="not_empty_field_mark">*</span></label></div><div class="elem_item"><input class="fc_field_10137849_1_3 styler" id="fc_field_1_3_block_id" name="1_3" type="text" value=""/></div></div></div><div class="fc_item fc_textarea fc_item_10137849_1_7" id="fc_item_1_7_block_id"><div class="label_under_hint"><label class="sector_title label_textarea" for="fc_field_1_7_block_id">Комментарий (не обязательно)</label></div><div class="elem_item"><textarea class="fc_field_10137849_1_7 styler" id="fc_field_1_7_block_id" name="1_7"></textarea></div></div><div class="fc_item fc_checkbox sector_required fc_item_10137849_1_6 fc_checkbox_one" id="fc_item_1_6_block_id"><div class="elem_item one"><input checked="" class="fc_field_10137849_1_6 styler" id="fc_field_1_6_block_id" name="1_6" type="checkbox" value="on"/></div><div class="label_under_hint sector_title force_position_right"><label class="sector_title force_position_right" for="fc_field_1_6_block_id">Даю своё согласие на обработку моих персональных данных, в соответствии с <a href="/privacy-policy/" rel="nofollow" target="_blank">политикой конфиденциальности</a><span class="not_empty_field_mark">*</span></label></div></div></div><div class="fc_item hnpot"><input name="name" type="text" value=""/></div><input name="form_name" type="hidden" value="FormConstructorForm"/><input name="form_id" type="hidden" value="10137849"/><div class="buttons"><input class="submit save styler" name="sendsave" type="submit" value="Отправить"/></div></form>
#  </div><div class="cleaner"></div><script type="text/javascript">if(typeof formLang == "undefined"){var formLang = new Object();}		formLang['file_not_select'] = 'Выберите файл';
#  		formLang['browse'] = 'Обзор...';
#  	var formStylization = true;
#  	$(function() {
#  		$('input.styler, select.styler').styler();
#  	});
#  	if(typeof formError == 'undefined'){
#  		var formError = new Object();
#  	}
#  	formError['FormConstructorForm'] = {"captcha":"\u041f\u043e\u043b\u0435 %s \u0437\u0430\u043f\u043e\u043b\u043d\u0435\u043d\u043e \u043d\u0435\u0432\u0435\u0440\u043d\u043e","email":"\u041f\u043e\u043b\u0435 %s \u0441\u043e\u0434\u0435\u0440\u0436\u0438\u0442 \u043d\u0435\u043a\u043e\u0440\u0440\u0435\u043a\u0442\u043d\u044b\u0439 E-Mail \u0430\u0434\u0440\u0435\u0441","not_attach_file":"\u0412 \u043f\u043e\u043b\u0435 %s \u043d\u0435\u043e\u0431\u0445\u043e\u0434\u0438\u043c\u043e \u043f\u0440\u0438\u043a\u0440\u0435\u043f\u0438\u0442\u044c \u0444\u0430\u0439\u043b","required":"\u041f\u043e\u043b\u0435 %s \u0434\u043e\u043b\u0436\u043d\u043e \u0431\u044b\u0442\u044c \u0437\u0430\u043f\u043e\u043b\u043d\u0435\u043d\u043e","checkbox_required":"\u0412 \u043f\u043e\u043b\u0435 %s \u0434\u043e\u043b\u0436\u043d\u043e \u0431\u044b\u0442\u044c \u0432\u044b\u0431\u0440\u0430\u043d\u043e \u0445\u043e\u0442\u044f \u0431\u044b \u043e\u0434\u043d\u043e \u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0435","radio_required":"\u0412 \u043f\u043e\u043b\u0435 %s \u0434\u043e\u043b\u0436\u043d\u043e \u0431\u044b\u0442\u044c \u0432\u044b\u0431\u0440\u0430\u043d\u043e \u043e\u0434\u043d\u043e \u0438\u0437 \u0437\u043d\u0430\u0447\u0435\u043d\u0438\u0439","invalid_format":"\u041f\u043e\u043b\u0435 %s \u0437\u0430\u043f\u043e\u043b\u043d\u0435\u043d\u043e \u043d\u0435\u0432\u0435\u0440\u043d\u043e","1_6":"\u0414\u043b\u044f \u043f\u0440\u043e\u0434\u043e\u043b\u0436\u0435\u043d\u0438\u044f \u0432\u044b \u0434\u043e\u043b\u0436\u043d\u044b \u043f\u0440\u0438\u043d\u044f\u0442\u044c \u0443\u0441\u043b\u043e\u0432\u0438\u044f \u043f\u043e\u043b\u0438\u0442\u0438\u043a\u0438 \u043a\u043e\u043d\u0444\u0438\u0434\u0435\u043d\u0446\u0438\u0430\u043b\u044c\u043d\u043e\u0441\u0442\u0438 \u0434\u0430\u043d\u043d\u043e\u0433\u043e \u0441\u0430\u0439\u0442\u0430"};
#  $(document).ready(function(){$("form.id77132").on("submit", function(){yaGoal(24527192, "zakaz-uslugi");; userScript("zakaz-uslugi"); return true;})});</script> </div>
#  <div class="adaptive-menu"><div class="close"></div></div>
#  <div class="header">
#  <div class="inner">
#  <div class="left">
#  <div class="row">
#  <div class="logo">
#  <a href="">
#  <span class="logo-row"><span class="logo-image"><p><img alt="" height="233" src="/uploadedFiles/images/Logo-Atmosfera-Krasoty.png" width="831"/></p></span>
#  <span class="logo-text">Атмосфера Красоты</span></span>
#  </a>
#  <div class="slogan"></div>
#  </div>
#  </div>
#  </div>
#  <div class="center">
#  <div class="burger">
#  <span></span>
#  <span></span>
#  <span></span>
#  </div>
#  <div class="lh_contact">
#  <p>Сеть салонов красоты:<strong><a href="tel:+73432885782"> +7 (343) 288 57 82</a></strong></p>
#  <p>Интернет магазин:<strong> <a href="tel:+73432168528">+7 (343) 216 85 28</a></strong></p>
#  <p>Учебный центр: <strong><a href="tel:+73432168528">+7 (343) 216 85 28</a></strong></p> <div class="header-buttons-wrap">
#  <div class="header-btn"><a href="http://www.malahit.com/online.html?id=65A9CB92-1962-4CCE-810D-DA5C789789AB&amp;wd=%D0%9F%D0%BD-%D0%92%D1%81&amp;wt=09:00%20%D0%BF%D0%BE%2021:00" target="_blank">Запись online</a></div>
#  <div class="header-btn modal_opener"><a href="/zakazat-zvonok/" target="_blank">Заказать звонок</a></div>
#  </div>
#  </div>
#  <div class="search">
#  <form action="https://salonak.ru/sitesearch/" class="uss_site_search" method="get">
#  <input class="uss_input_name" id="search_10107144_2761" name="search" placeholder="Поиск по сайту" type="text" value=""/>
#  <input class="uss_submit" type="submit" value=""/>
#  </form><script type="text/javascript">
#  				$(document).ready(function() {
#  					$('#search_10107144_2761').autocomplete('sitesearch/', {
#  						selectFirst: false,
#  						inputClass : 'uss_autocomplete_input',
#  						resultsClass: 'uss_autocomplete_results',
#  						matchContains: 'word',
#  						selectFirst: true,
#  						cacheLength: 1,
#  						delay: 500,
#  						minLength: 3,
#  						formatItem: function(item){
#  							var line = '';
#  							//изображение
#  							if(item[1]){
#  								line += '<span class="image">' + item[1] + '</span>';
#  							}
#
#  							//заголовок
#  							line += '<span class="title">' + item[0] + '</span>';
#
#  							//цена
#  							if(item[2]){
#  								line += '<span class="price">' + item[2] + '</span>';
#  							}
#  							return line;
#  						}
#  					});
#
#  					$(window).resize(function(){
#  						$('.uss_autocomplete_results').hide();
#  					});
#  					$('#search_10107144_2761').result(function(event, data){console.log(data[1]); $(this).closest('form').submit() });});</script> </div>
#  </div>
#  <div class="right">
#  <div class="auth">
#  <span class="enter"><a href="https://salonak.ru/enter/">Вход</a></span> / <span class="registration"><a href="https://salonak.ru/registration/">Регистрация</a></span>
#  </div>
#  <div class="search">
#  <form action="https://salonak.ru/sitesearch/" class="uss_site_search" method="get">
#  <input class="uss_input_name" id="search_10107144_6151" name="search" placeholder="Поиск по сайту" type="text" value=""/>
#  <input class="uss_submit" type="submit" value=""/>
#  </form><script type="text/javascript">
#  				$(document).ready(function() {
#  					$('#search_10107144_6151').autocomplete('sitesearch/', {
#  						selectFirst: false,
#  						inputClass : 'uss_autocomplete_input',
#  						resultsClass: 'uss_autocomplete_results',
#  						matchContains: 'word',
#  						selectFirst: true,
#  						cacheLength: 1,
#  						delay: 500,
#  						minLength: 3,
#  						formatItem: function(item){
#  							var line = '';
#  							//изображение
#  							if(item[1]){
#  								line += '<span class="image">' + item[1] + '</span>';
#  							}
#
#  							//заголовок
#  							line += '<span class="title">' + item[0] + '</span>';
#
#  							//цена
#  							if(item[2]){
#  								line += '<span class="price">' + item[2] + '</span>';
#  							}
#  							return line;
#  						}
#  					});
#
#  					$(window).resize(function(){
#  						$('.uss_autocomplete_results').hide();
#  					});
#  					$('#search_10107144_6151').result(function(event, data){console.log(data[1]); $(this).closest('form').submit() });});</script> </div>
#  <div class="basket">
#  <a class="basket-link" href="/basket/"></a>
#  <div class="uss_widget uss_widget_basket uss_basket_mini uss_basket_wrapper empty" data-countword="" data-priceword=""><div class="uss_widget_outer_content basket_widget_inner empty"><div class="amounts uss_hidden"><span class="countword"></span> <span id="uss_block_basket_amount"></span></div><div class="totals uss_hidden"><span class="priceword"></span> <span id="uss_block_basket_totals"></span></div><p>Ваша корзина пуста</p></div></div>
#  </div> </div>
#  </div>
#  </div>
#  <div class="menu">
#  <div class="inner">
#  <ul><li class="active first"><a class="active first" href="katalog-tovarov/" title="Профессиональная косметика для волос и ногтей">Интернет-магазин</a><ul class="submenu"><li class="first"><a class="first" href="/katalog-tovarov/" title="Каталог товаров">Каталог товаров</a></li><li><a href="katalog-tovarov/dostavka/" title="Доставка и оплата">Доставка и оплата</a></li><li><a href="katalog-tovarov/akcii-tk/" title="Скидки и Акции">Скидки и Акции </a></li><li><a href="katalog-tovarov/torgovaya-kompaniya/" title='О торговой компании "Атмосфера Красоты"'>О компании</a></li><li><a href="katalog-tovarov/masteram/" title="Специальные предложения для мастеров и салонов">Для мастеров и салонов</a></li><li><a href="katalog-tovarov/news/" title="Новости">Новости</a></li><li><a href="katalog-tovarov/otzyvy/" title="Отзывы">Отзывы</a></li><li><a href="katalog-tovarov/o-torgovoy-kompanii/" title="Вакансии интернет-магазина">Вакансии</a><ul class="submenu"><li class="first last"><a class="first last" href="katalog-tovarov/o-torgovoy-kompanii/nashi-filialy-i-kontakty/" title="Торговый представитель">Торговый представитель</a></li></ul></li><li class="last"><a class="last" href="katalog-tovarov/kontakty-1/" title="Контакты магазина">Контакты</a></li></ul></li><li><a href="uslugi-salona/" title="Услуги салонов «Атмосфера Красоты» ">Салоны красоты</a><ul class="submenu"><li class="first"><a class="first" href="/uslugi-salona/" title="Услуги">Услуги</a></li><li><a href="uslugi-salona/salon-krasoty/" title='О сети салонов "Атмосфера Красоты"'>О Салонах</a></li><li><a href="uslugi-salona/stoimost-nashih-uslug/" title="Стоимость услуг">Стоимость услуг</a><ul class="submenu"><li class="first"><a class="first" href="uslugi-salona/stoimost-nashih-uslug/parikmaherskiy-zal/" title="Прайс-лист на парикмахерские услуги">Парикмахерский зал</a></li><li><a href="uslugi-salona/stoimost-nashih-uslug/manikyurnyypedikyurnyy-kabinet/" title="Маникюрный / педикюрный кабинет">Маникюрный / педикюрный кабинет</a></li><li><a href="uslugi-salona/stoimost-nashih-uslug/svadebnyy-i-vecherniy-makiyazh/" title="Макияж">Макияж</a></li><li><a href="uslugi-salona/stoimost-nashih-uslug/naraschivanie-resnic-i-oformlenie-brovey/" title="Стоимость окрашивания ресниц и оформления бровей">Оформление ресниц и бровей</a></li><li><a href="uslugi-salona/stoimost-nashih-uslug/kosmetologiya/" title="Уход за лицом">Уход за лицом</a></li><li><a href="uslugi-salona/stoimost-nashih-uslug/massazh-depilyaciya-obertyvanie/" title="Уход за телом ">Уход за телом </a></li><li><a href="uslugi-salona/stoimost-nashih-uslug/inekcionnaya-kosmetologiya/" title='Стоимость услуг инъекционной косметологии в центрах "Атмосфера Красоты"'>Инъекционная косметология </a></li><li class="last"><a class="last" href="uslugi-salona/stoimost-nashih-uslug/apparatnaya-kosmetologiya-dlya-lica-i-tela/" title="Стоимость аппаратной косметологии для лица и тела">Аппаратная косметология для лица и тела</a></li></ul></li><li><a href="uslugi-salona/actions/" title='Акции сети салонов "Атмосфера красоты"'>Акции салонов</a></li><li><a href="uslugi-salona/fotogalereya/" title='Фотогалерея сети салонов "Атмосфера Красоты"'>Фотогалерея</a></li><li><a href="uslugi-salona/licenziya/" title='Медицинская лицензия "Атмосфера Красоты"'>Лицензия</a></li><li><a href="uslugi-salona/vakansii/" title="Вакансии салона красоты">Вакансии</a><ul class="submenu"><li class="first"><a class="first" href="uslugi-salona/vakansii/kosmetolog/" title="Косметолог">Косметолог</a></li><li><a href="uslugi-salona/vakansii/parikmaher/" title="Парикмахер">Парикмахер</a></li><li><a href="uslugi-salona/vakansii/uchenik-parikmahera/" title="Ученик парикмахера ">Ученик парикмахера </a></li><li><a href="uslugi-salona/vakansii/manikyurist/" title="Маникюрист ">Маникюрист </a></li><li><a href="uslugi-salona/vakansii/administrator/" title="Администратор">Администратор</a></li><li class="last"><a class="last" href="uslugi-salona/vakansii/uborschica-pomoschnik-administrat ...
#  </div>
#  <div class="container">
#  <div class="inner">
#  <div class="aside aside-left">
#  <div class="aside-block aside-catalog">
#  <ul class="uss_eshop_menu totalItems_over10"><li class="first"><a class="first" href="https://salonak.ru/katalog-tovarov/okrashivanie/">Профессиональное окрашивание</a></li><li><a href="https://salonak.ru/katalog-tovarov/sedstva-po-uhodu-za-volosami/">Профессиональные средства для волос</a></li><li><a href="https://salonak.ru/katalog-tovarov/lechenie-volos/">Интенсивное восстановление и лечение волос</a></li><li><a href="https://salonak.ru/katalog-tovarov/stayling-ukladka/">Средства для укладки волос</a></li><li><a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/">Мужская косметика</a></li><li><a href="https://salonak.ru/katalog-tovarov/bigudi-i-aksessuary-dlya-zavivki/">Составы и аксессуары для долговременной укладки</a></li><li><a href="https://salonak.ru/katalog-tovarov/vse-dlya-manikyura-i-pedikyura/">Материалы для маникюра и педикюра</a></li><li><a href="https://salonak.ru/katalog-tovarov/depilyaciya/">Средства для депиляции</a></li><li><a href="https://salonak.ru/katalog-tovarov/odnorazovaya-produkciya-i-dezinfektory/">Одноразовая продукция</a></li><li><a href="https://salonak.ru/katalog-tovarov/dlya-kosmetologov/">Для косметологов</a></li><li><a href="https://salonak.ru/katalog-tovarov/dezinfektory/">Дезинфекция и стерилизация</a></li><li><a href="https://salonak.ru/katalog-tovarov/elektropribory-i-aksessuary/">Парикмахерские инструменты и электроприборы</a></li><li class="last"><a class="last" href="https://salonak.ru/katalog-tovarov/dlya-solyariya/">Крема для солярия</a></li></ul>
#  </div> <div class="aside-block aside-news">
#  <div class="h3">Новости</div><div class="uss_widget_outer_content"><div class="news_block_item first"><div class="info"><div class="date">27.04.2024</div><div class="title"><a href="https://salonak.ru/katalog-tovarov/news/priglashaem-na-seminar-13-23-maya/"><span class="tspan">Приглашаем на семинары</span></a></div><div class="preview"><p>15 мая Семинар по уходовым средствам &amp; SPA процедурам от Kaaral<br/> 23 мая Семинар по красителям Kaaral</p></div></div></div><div class="news_block_item"><div class="info"><div class="date">03.12.2023</div><div class="title"><a href="https://salonak.ru/katalog-tovarov/news/novogodnie-nabory-uhodovyh-sredstv-i-aksessuarov-dlya-volos/"><span class="tspan">Подарочные наборы уходовых средств и аксессуаров для волос. ХИТы 2023 года</span></a></div><div class="preview"><p>Подарите лучшую заботу о волосах себе и своим близким!</p></div></div></div><div class="news_block_item last"><div class="info"><div class="date">17.05.2023</div><div class="title"><a href="https://salonak.ru/katalog-tovarov/news/mens-master-professional-muzhskaya-professionalnaya-kosmetika/"><span class="tspan">Men's Master Professional - мужская профессиональная косметика оптом и в розницу</span></a></div><div class="preview"></div></div></div></div>
#  <div class="buttons"><a class="more btn" href="/katalog-tovarov/news/">Все новости</a></div>
#  </div> <div class="aside-block aside-banner">
#  <div class="baner-slide">
#  <a class="baner-slide-link" href="/katalog-tovarov/lechenie-volos/sredstva-dlya-vosstanovleniya-okrashennykh-i-povrezhdennykh-v/s-d-u-cocareplex-nabor-dlya-okrashivaniya-i-vosstanovleniya-v-1/"></a>
#  <div class="image">
#  <img alt="" src="/uploadedFiles/newsimages/icons/260x311_cropped/sdu-bingo.jpg"/>
#  </div>
#  <div class="info">
#  <div class="title lalala"></div>
#  </div>
#  </div>
#  </div> </div>
#  <div class="content">
#  <div class="bread"><a class="breadcrumbs_main" href="https://salonak.ru">Главная</a><span class="devider">/</span>Интернет-магазин</div> <h1>Профессиональная косметика для волос и ногтей</h1> <div class="context x3 noflex">
#  <div class="section section_eshop id_10107648"><div class="uss_section_content"><div class="uss_shop_block_cat uss_shop_cats">
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/okrashivanie/"><img alt="Профессиональное окрашивание - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/okrashivanie.jpg" title="Профессиональное окрашивание - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/okrashivanie/">Профессиональное окрашивание</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/sedstva-po-uhodu-za-volosami/"><img alt="Профессиональные средства для волос - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/wpid-2B048FC8EC6EED05B84C4DB0DCCC0985.jpg" title="Профессиональные средства для волос - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/sedstva-po-uhodu-za-volosami/">Профессиональные средства для волос</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/lechenie-volos/"><img alt="Интенсивное восстановление и лечение волос - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/Keratinovoe-vyipryamlenie-volos-samostoyatelno.jpg" title="Интенсивное восстановление и лечение волос - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/lechenie-volos/">Интенсивное восстановление и лечение волос</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/stayling-ukladka/"><img alt="Средства для укладки волос - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/dscf8395-r.png" title="Средства для укладки волос - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/stayling-ukladka/">Средства для укладки волос</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/"><img alt="Мужская косметика - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/mens-master-professional-dlya-muzhchin.jpg" title="Мужская косметика - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/">Мужская косметика</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/bigudi-i-aksessuary-dlya-zavivki/"><img alt="Составы и аксессуары для долговременной укладки - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/himiya.jpg" title="Составы и аксессуары для долговременной укладки - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/bigudi-i-aksessuary-dlya-zavivki/">Составы и аксессуары для долговременной укладки</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/vse-dlya-manikyura-i-pedikyura/"><img alt="Материалы для маникюра и педикюра - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/tuy-dokucu-epila.jpg" title="Материалы для маникюра и педикюра - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/vse-dlya-manikyura-i-pedikyura/">Материалы для маникюра и педикюра</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/depilyaciya/"><img alt="Средства для депиляции - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/11e24a595cb2779eff6be03aff132d4b.jpg" title="Средства для депиляции - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/depilyaciya/">Средства для депиляции</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/odnorazovaya-produkciya-i-dezinfektory/"><img alt="Одноразовая продукция - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/164.jpg" title="Одноразовая продукция - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/odnorazovaya-produkciya-i-dezinfektory/">Одноразовая продукция</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/dlya-kosmetologov/"><img alt="Для косметологов - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/164_3.jpg" title="Для косметологов - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/dlya-kosmetologov/">Для косметологов</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/dezinfektory/"><img alt="Дезинфекция и стерилизация - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/522_0c895929174_2.jpg" title="Дезинфекция и стерилизация - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/dezinfektory/">Дезинфекция и стерилизация</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/elektropribory-i-aksessuary/"><img alt="Парикмахерские инструменты и электроприборы - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/522_0c895929174.jpg" title="Парикмахерские инструменты и электроприборы - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/elektropribory-i-aksessuary/">Парикмахерские инструменты и электроприборы</a>
#  </div>
#  </div>
#  <div class="uss_shop_category size240x240" style="width:246px;">
#  <div class="uss_shop_cat_img_wrap">
#  <div class="uss_shop_cat_img" style="width: 240px;height: 240px;">
#  <a href="https://salonak.ru/katalog-tovarov/dlya-solyariya/"><img alt="Крема для солярия - salonak.ru - Екатеринбург" src="/uploadedFiles/eshopimages/icons/240x240_cropped/krema-dlya-zagara-v-solyarii-optom-ekaterinburg.png" title="Крема для солярия - salonak.ru - Екатеринбург"/></a>
#  </div>
#  </div>
#  <div class="uss_shop_cat_name">
#  <a href="https://salonak.ru/katalog-tovarov/dlya-solyariya/">Крема для солярия</a>
#  </div>
#  </div>
#  </div>
#  <div class="uss_cleaner"></div><div class="uss_eshop_filters"><noindex><div class="uss_eshop_filters_block simple_filters">
#  <form action="https://salonak.ru/katalog-tovarov/" id="uss_block_filters" method="get" name="uss_block_filters"><div class="filter_price filter_item"><label>Цена</label><div class="inputs"> от<input class="filter_ajax_update styler" name="minprice" type="text" value=""/> до<input class="filter_ajax_update styler" name="maxprice" type="text" value=""/></div></div><div class="filter_producer filter_item"><label class="for_styler">Производитель</label><select class="filter_ajax_update styler" name="producer"><option value="0">Любой</option><option value="ACSIOMA">ACSIOMA</option><option value="BINGO">BINGO</option><option value="BRIZGER">BRIZGER</option><option value="DE VELOURS">DE VELOURS</option><option value="DEPILFLAX">DEPILFLAX</option><option value="GIORGIO CAPACHINI">GIORGIO CAPACHINI</option><option value="HAIRWAY">HAIRWAY</option><option value="HW">HW</option><option value="IGRO">IGRO</option><option value="J.CURL">J.CURL</option><option value="KAARAL">KAARAL</option><option value="LEVISSIME">LEVISSIME</option><option value="LUXOR PROFESSIONAL">LUXOR PROFESSIONAL</option><option value="MARK SHMIDT">MARK SHMIDT</option><option value="MS.NAIL">MS.NAIL</option><option value="MS.NAILS">MS.NAILS</option><option value="Master Professional">Master Professional</option><option value="Melon Pro ">Melon Pro </option><option value="Men's Master Professional">Men's Master Professional</option><option value="NIRVEL">NIRVEL</option><option value="Natural Beauty">Natural Beauty</option><option value="Patrisa Nail">Patrisa Nail</option><option value="REFECTOCIL">REFECTOCIL</option><option value="S.D.U. CAREPLEX">S.D.U. CAREPLEX</option><option value="Solbianca">Solbianca</option><option value="Soleo">Soleo</option><option value="Starpil">Starpil</option><option value="Sun Luxe Professional">Sun Luxe Professional</option><option value="jRL">jRL</option><option value="Диадем">Диадем</option><option value="Иалия">Иалия</option><option value="Италия">Италия</option><option value="ЧИСТОВЬЕ">ЧИСТОВЬЕ</option></select></div>
#  <div class="filter_submit">
#  <input class="filter_ajax_update styler" type="submit" value="Искать"/>
#  </div>
#  </form>
#  </div><script type="text/javascript">$(document).ready(function(){
#  					updateContent("#eshop_pos_content");
#  				});</script></noindex></div><div class="uss_cleaner"></div><div id="eshop_pos_content"><div class="uss_eshop_sort_block"><div class="sort_settings"><noindex>Сортировать по: <a href="katalog-tovarov/?sort=price_asc">Цене</a>
#  <span class="arrow">
#  <a href="katalog-tovarov/?sort=price_asc">↑</a>
#  <a href="katalog-tovarov/?sort=price_desc">↓</a>
#  </span>  <a href="katalog-tovarov/?sort=title_asc">Названию</a>
#  <span class="arrow">
#  <a href="katalog-tovarov/?sort=title_asc">↑</a>
#  <a href="katalog-tovarov/?sort=title_desc">↓</a>
#  </span></noindex></div><div class="filter_show_by_links"><form method="GET" name="show_by_links">Выводить по <select class="show_by_count styler" name="show_by" onchange="this.form.submit();"><option value="10">10</option><option value="20">20</option><option value="30">30</option><option selected="" value="40">40</option><option value="50">50</option><option value="100">100</option></select></form></div></div><div class="uss_cleaner"></div><div class="uss_shop_blocks_view">
#  <div class="uss_eshop_item order_one buyclick_available" style="width: 174px;">
#  <div class="posimg_item">
#  <div class="uss_img_holder_outer" style="width: 176px;">
#  <div class="uss_img_holder" style="width: 170px; height: 170px;">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/stimuliruyuschee-maslo-dlya-borody-i-usov-mens-master/" title="Стимулирующее масло для бороды и усов MEN’S MASTER 30 мл - salonak.ru - Екатеринбург">
#  <img alt="Стимулирующее масло для бороды и усов MEN’S MASTER 30 мл - salonak.ru - Екатеринбург" class="pos_main_img" src="/uploadedFiles/eshopimages/icons/170x170/2021-12-13_17-19-57.jpg"/>
#  </a> <div class="uss_eshop_icons icons_display_place_2"><div class="one_icon new_icon"><a class="" href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/stimuliruyuschee-maslo-dlya-borody-i-usov-mens-master/" title="Новинка"><img alt="Новинка" src="https://salonak.ru/uploadedFiles/eshopicons/new-icon.png" title="Новинка"/></a></div></div> </div>
#  </div>
#  </div>
#  <div class="uss_shop_name">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/stimuliruyuschee-maslo-dlya-borody-i-usov-mens-master/" title="Подробное описание товара">Стимулирующее масло для бороды и усов MEN’S MASTER 30 мл</a>
#  </div>
#  <div class="uss_shop_price">
#  <span class="actual_price"><em class="price_class" data-clear-price="711">711</em> <em class="currency_class">руб.</em></span>
#  </div>
#  <div class="uss_shop_by"><a class="add_to_cart buy_from_cart greater_than_zero uss_pos_buttons" data-item-id="19305080" data-title-tocart="Купить" onclick="return changeItemInBasket(this,19305080,false,false,0, '');" title="Купить">Купить</a><div class="text_after_order_19305080" style="display:none;">Оформить заказ</div></div>
#  <div class="uss_shop_by uss_shop_buy_one_click"><a class="add_to_cart buy_one_click uss_pos_buttons" data-pos-id="19305080" data-url="https://salonak.ru/katalog-tovarov/" title="Купить в 1 клик">Купить в 1 клик</a></div>
#  <div class="uss_compare_by"><a class="add_to_compare uss_pos_buttons" data-already-title="В сравнении" data-url="/katalog-tovarov/?add_compare=19305080" onclick="addCompare(this, 19305080); return false;" title="Сравнить">Сравнить</a></div>
#  <div class="uss_shop_producer"><strong>Производитель:</strong> Men's Master Professional</div>
#  <div class="uss_shop_uid"><strong>Код:</strong> 1031091015-1</div>
#  </div>
#  <div class="uss_eshop_item order_one buyclick_available" style="width: 174px;">
#  <div class="posimg_item">
#  <div class="uss_img_holder_outer" style="width: 176px;">
#  <div class="uss_img_holder" style="width: 170px; height: 170px;">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-okrashivayuschiy-dlya-volos-mens-master-chernyy/" title="Шампунь Окрашивающий для волос MEN’S MASTER Чёрный 1 шт. 25 мл - salonak.ru - Екатеринбург">
#  <img alt="Шампунь Окрашивающий для волос MEN’S MASTER Чёрный 1 шт. 25 мл - salonak.ru - Екатеринбург" class="pos_main_img" src="/uploadedFiles/eshopimages/icons/170x170/2021-12-13_17-10-28.jpg"/>
#  </a> <div class="uss_eshop_icons icons_display_place_2"><div class="one_icon new_icon"><a class="" href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-okrashivayuschiy-dlya-volos-mens-master-chernyy/" title="Новинка"><img alt="Новинка" src="https://salonak.ru/uploadedFiles/eshopicons/new-icon.png" title="Новинка"/></a></div></div> </div>
#  </div>
#  </div>
#  <div class="uss_shop_name">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-okrashivayuschiy-dlya-volos-mens-master-chernyy/" title="Подробное описание товара">Шампунь Окрашивающий для волос MEN’S MASTER Чёрный 1 шт. 25 мл</a>
#  </div>
#  <div class="uss_shop_price">
#  <span class="actual_price"><em class="price_class" data-clear-price="106">106</em> <em class="currency_class">руб.</em></span>
#  </div>
#  <div class="uss_shop_by"><a class="add_to_cart buy_from_cart greater_than_zero uss_pos_buttons" data-item-id="19305079" data-title-tocart="Купить" onclick="return changeItemInBasket(this,19305079,false,false,0, '');" title="Купить">Купить</a><div class="text_after_order_19305079" style="display:none;">Оформить заказ</div></div>
#  <div class="uss_shop_by uss_shop_buy_one_click"><a class="add_to_cart buy_one_click uss_pos_buttons" data-pos-id="19305079" data-url="https://salonak.ru/katalog-tovarov/" title="Купить в 1 клик">Купить в 1 клик</a></div>
#  <div class="uss_compare_by"><a class="add_to_compare uss_pos_buttons" data-already-title="В сравнении" data-url="/katalog-tovarov/?add_compare=19305079" onclick="addCompare(this, 19305079); return false;" title="Сравнить">Сравнить</a></div>
#  <div class="uss_shop_producer"><strong>Производитель:</strong> Men's Master Professional</div>
#  <div class="uss_shop_uid"><strong>Код:</strong> 1031091009</div>
#  </div>
#  <div class="uss_eshop_item order_one buyclick_available" style="width: 174px;">
#  <div class="posimg_item">
#  <div class="uss_img_holder_outer" style="width: 176px;">
#  <div class="uss_img_holder" style="width: 170px; height: 170px;">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-okrashivayuschiy-dlya-volos-mens-master-korichnevyy/" title="Шампунь окрашивающий для волос MEN’S MASTER Коричневый 1 шт. 25 мл - salonak.ru - Екатеринбург">
#  <img alt="Шампунь окрашивающий для волос MEN’S MASTER Коричневый 1 шт. 25 мл - salonak.ru - Екатеринбург" class="pos_main_img" src="/uploadedFiles/eshopimages/icons/170x170/shampun-okrashivayuschiy-dlya-volos-mens-master-korichnevyy.jpg"/>
#  </a> <div class="uss_eshop_icons icons_display_place_2"><div class="one_icon new_icon"><a class="" href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-okrashivayuschiy-dlya-volos-mens-master-korichnevyy/" title="Новинка"><img alt="Новинка" src="https://salonak.ru/uploadedFiles/eshopicons/new-icon.png" title="Новинка"/></a></div></div> </div>
#  </div>
#  </div>
#  <div class="uss_shop_name">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-okrashivayuschiy-dlya-volos-mens-master-korichnevyy/" title="Подробное описание товара">Шампунь окрашивающий для волос MEN’S MASTER Коричневый 1 шт. 25 мл</a>
#  </div>
#  <div class="uss_shop_price">
#  <span class="actual_price"><em class="price_class" data-clear-price="106">106</em> <em class="currency_class">руб.</em></span>
#  </div>
#  <div class="uss_shop_by"><a class="add_to_cart buy_from_cart greater_than_zero uss_pos_buttons" data-item-id="19305078" data-title-tocart="Купить" onclick="return changeItemInBasket(this,19305078,false,false,0, '');" title="Купить">Купить</a><div class="text_after_order_19305078" style="display:none;">Оформить заказ</div></div>
#  <div class="uss_shop_by uss_shop_buy_one_click"><a class="add_to_cart buy_one_click uss_pos_buttons" data-pos-id="19305078" data-url="https://salonak.ru/katalog-tovarov/" title="Купить в 1 клик">Купить в 1 клик</a></div>
#  <div class="uss_compare_by"><a class="add_to_compare uss_pos_buttons" data-already-title="В сравнении" data-url="/katalog-tovarov/?add_compare=19305078" onclick="addCompare(this, 19305078); return false;" title="Сравнить">Сравнить</a></div>
#  <div class="uss_shop_producer"><strong>Производитель:</strong> Men's Master Professional</div>
#  <div class="uss_shop_uid"><strong>Код:</strong> 1031091010</div>
#  </div>
#  <div class="uss_eshop_item order_one buyclick_available" style="width: 174px;">
#  <div class="posimg_item">
#  <div class="uss_img_holder_outer" style="width: 176px;">
#  <div class="uss_img_holder" style="width: 170px; height: 170px;">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-stimuliruyuschiy-krasnyy-perec-kofein-i-hmel/" title='Шампунь Стимулирующий "Красный перец, кофеин и хмель" MEN’S MASTER 260 мл - salonak.ru - Екатеринбург'>
#  <img alt='Шампунь Стимулирующий "Красный перец, кофеин и хмель" MEN’S MASTER 260 мл - salonak.ru - Екатеринбург' class="pos_main_img" src="/uploadedFiles/eshopimages/icons/170x170/2021-12-13_16-55-19.jpg"/>
#  </a> <div class="uss_eshop_icons icons_display_place_2"><div class="one_icon new_icon"><a class="" href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-stimuliruyuschiy-krasnyy-perec-kofein-i-hmel/" title="Новинка"><img alt="Новинка" src="https://salonak.ru/uploadedFiles/eshopicons/new-icon.png" title="Новинка"/></a></div></div> </div>
#  </div>
#  </div>
#  <div class="uss_shop_name">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-stimuliruyuschiy-krasnyy-perec-kofein-i-hmel/" title="Подробное описание товара">Шампунь Стимулирующий "Красный перец, кофеин и хмель" MEN’S MASTER 260 мл</a>
#  </div>
#  <div class="uss_shop_price">
#  <span class="actual_price"><em class="price_class" data-clear-price="765">765</em> <em class="currency_class">руб.</em></span>
#  </div>
#  <div class="uss_shop_by"><a class="add_to_cart buy_from_cart greater_than_zero uss_pos_buttons" data-item-id="19305077" data-title-tocart="Купить" onclick="return changeItemInBasket(this,19305077,false,false,0, '');" title="Купить">Купить</a><div class="text_after_order_19305077" style="display:none;">Оформить заказ</div></div>
#  <div class="uss_shop_by uss_shop_buy_one_click"><a class="add_to_cart buy_one_click uss_pos_buttons" data-pos-id="19305077" data-url="https://salonak.ru/katalog-tovarov/" title="Купить в 1 клик">Купить в 1 клик</a></div>
#  <div class="uss_compare_by"><a class="add_to_compare uss_pos_buttons" data-already-title="В сравнении" data-url="/katalog-tovarov/?add_compare=19305077" onclick="addCompare(this, 19305077); return false;" title="Сравнить">Сравнить</a></div>
#  <div class="uss_shop_producer"><strong>Производитель:</strong> Men's Master Professional</div>
#  <div class="uss_shop_uid"><strong>Код:</strong> 1031091006</div>
#  </div>
#  <div class="uss_eshop_item order_one buyclick_available" style="width: 174px;">
#  <div class="posimg_item">
#  <div class="uss_img_holder_outer" style="width: 176px;">
#  <div class="uss_img_holder" style="width: 170px; height: 170px;">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-detoks-ugol-i-repey-mens-master-260-ml/" title='Шампунь Детокс "Уголь и репей" MEN’S MASTER 260 мл - salonak.ru - Екатеринбург'>
#  <img alt='Шампунь Детокс "Уголь и репей" MEN’S MASTER 260 мл - salonak.ru - Екатеринбург' class="pos_main_img" src="/uploadedFiles/eshopimages/icons/170x170/2021-12-13_16-57-54.jpg"/>
#  </a> <div class="uss_eshop_icons icons_display_place_2"><div class="one_icon new_icon"><a class="" href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-detoks-ugol-i-repey-mens-master-260-ml/" title="Новинка"><img alt="Новинка" src="https://salonak.ru/uploadedFiles/eshopicons/new-icon.png" title="Новинка"/></a></div></div> </div>
#  </div>
#  </div>
#  <div class="uss_shop_name">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/shampun-detoks-ugol-i-repey-mens-master-260-ml/" title="Подробное описание товара">Шампунь Детокс "Уголь и репей" MEN’S MASTER 260 мл</a>
#  </div>
#  <div class="uss_shop_price">
#  <span class="actual_price"><em class="price_class" data-clear-price="816">816</em> <em class="currency_class">руб.</em></span>
#  </div>
#  <div class="uss_shop_by"><a class="add_to_cart buy_from_cart greater_than_zero uss_pos_buttons" data-item-id="19305076" data-title-tocart="Купить" onclick="return changeItemInBasket(this,19305076,false,false,0, '');" title="Купить">Купить</a><div class="text_after_order_19305076" style="display:none;">Оформить заказ</div></div>
#  <div class="uss_shop_by uss_shop_buy_one_click"><a class="add_to_cart buy_one_click uss_pos_buttons" data-pos-id="19305076" data-url="https://salonak.ru/katalog-tovarov/" title="Купить в 1 клик">Купить в 1 клик</a></div>
#  <div class="uss_compare_by"><a class="add_to_compare uss_pos_buttons" data-already-title="В сравнении" data-url="/katalog-tovarov/?add_compare=19305076" onclick="addCompare(this, 19305076); return false;" title="Сравнить">Сравнить</a></div>
#  <div class="uss_shop_producer"><strong>Производитель:</strong> Men's Master Professional</div>
#  <div class="uss_shop_uid"><strong>Код:</strong> 1031091005</div>
#  </div>
#  <div class="uss_eshop_item order_one buyclick_available" style="width: 174px;">
#  <div class="posimg_item">
#  <div class="uss_img_holder_outer" style="width: 176px;">
#  <div class="uss_img_holder" style="width: 170px; height: 170px;">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/bodryaschee-mylo-dlya-tela-i-volos-vodorosli-i-myata-mens/" title='Бодрящее мыло для тела и волос "Водоросли и мята" MEN’S MASTER 260 мл - salonak.ru - Екатеринбург'>
#  <img alt='Бодрящее мыло для тела и волос "Водоросли и мята" MEN’S MASTER 260 мл - salonak.ru - Екатеринбург' class="pos_main_img" src="/uploadedFiles/eshopimages/icons/170x170/2021-12-13_16-59-01.jpg"/>
#  </a> <div class="uss_eshop_icons icons_display_place_2"><div class="one_icon new_icon"><a class="" href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/bodryaschee-mylo-dlya-tela-i-volos-vodorosli-i-myata-mens/" title="Новинка"><img alt="Новинка" src="https://salonak.ru/uploadedFiles/eshopicons/new-icon.png" title="Новинка"/></a></div></div> </div>
#  </div>
#  </div>
#  <div class="uss_shop_name">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/bodryaschee-mylo-dlya-tela-i-volos-vodorosli-i-myata-mens/" title="Подробное описание товара">Бодрящее мыло для тела и волос "Водоросли и мята" MEN’S MASTER 260 мл</a>
#  </div>
#  <div class="uss_shop_price">
#  <span class="actual_price"><em class="price_class" data-clear-price="770">770</em> <em class="currency_class">руб.</em></span>
#  </div>
#  <div class="uss_shop_by"><a class="add_to_cart buy_from_cart greater_than_zero uss_pos_buttons" data-item-id="19305075" data-title-tocart="Купить" onclick="return changeItemInBasket(this,19305075,false,false,0, '');" title="Купить">Купить</a><div class="text_after_order_19305075" style="display:none;">Оформить заказ</div></div>
#  <div class="uss_shop_by uss_shop_buy_one_click"><a class="add_to_cart buy_one_click uss_pos_buttons" data-pos-id="19305075" data-url="https://salonak.ru/katalog-tovarov/" title="Купить в 1 клик">Купить в 1 клик</a></div>
#  <div class="uss_compare_by"><a class="add_to_compare uss_pos_buttons" data-already-title="В сравнении" data-url="/katalog-tovarov/?add_compare=19305075" onclick="addCompare(this, 19305075); return false;" title="Сравнить">Сравнить</a></div>
#  <div class="uss_shop_producer"><strong>Производитель:</strong> Men's Master Professional</div>
#  <div class="uss_shop_uid"><strong>Код:</strong> 1031091004</div>
#  </div>
#  <div class="uss_eshop_item order_one buyclick_available" style="width: 174px;">
#  <div class="posimg_item">
#  <div class="uss_img_holder_outer" style="width: 176px;">
#  <div class="uss_img_holder" style="width: 170px; height: 170px;">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/tonik-dlya-ukladki-volos-i-borody-mens-master/" title="Тоник для укладки волос и бороды MEN’S MASTER 100 мл - salonak.ru - Екатеринбург">
#  <img alt="Тоник для укладки волос и бороды MEN’S MASTER 100 мл - salonak.ru - Екатеринбург" class="pos_main_img" src="/uploadedFiles/eshopimages/icons/170x170/2021-12-13_17-21-07.jpg"/>
#  </a> <div class="uss_eshop_icons icons_display_place_2"><div class="one_icon new_icon"><a class="" href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/tonik-dlya-ukladki-volos-i-borody-mens-master/" title="Новинка"><img alt="Новинка" src="https://salonak.ru/uploadedFiles/eshopicons/new-icon.png" title="Новинка"/></a></div></div> </div>
#  </div>
#  </div>
#  <div class="uss_shop_name">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/tonik-dlya-ukladki-volos-i-borody-mens-master/" title="Подробное описание товара">Тоник для укладки волос и бороды MEN’S MASTER 100 мл</a>
#  </div>
#  <div class="uss_shop_price">
#  <span class="actual_price"><em class="price_zero_class price_zero_class_for_amount" data-currency="руб.">Цена по запросу</em></span>
#  </div>
#  <div class="uss_shop_by"><a class="add_to_cart buy_from_cart equal_zero uss_pos_buttons" data-item-id="19305074" data-title-tocart="Заказать " onclick="return changeItemInBasket(this,19305074,false,false,0, '');" title="Заказать ">Заказать </a><div class="text_after_order_19305074" style="display:none;">Оформить заказ</div></div>
#  <div class="uss_shop_by uss_shop_buy_one_click"><a class="add_to_cart buy_one_click uss_pos_buttons" data-pos-id="19305074" data-url="https://salonak.ru/katalog-tovarov/" title="Купить в 1 клик">Купить в 1 клик</a></div>
#  <div class="uss_compare_by"><a class="add_to_compare uss_pos_buttons" data-already-title="В сравнении" data-url="/katalog-tovarov/?add_compare=19305074" onclick="addCompare(this, 19305074); return false;" title="Сравнить">Сравнить</a></div>
#  <div class="uss_shop_producer"><strong>Производитель:</strong> Men's Master Professional</div>
#  <div class="uss_shop_uid"><strong>Код:</strong> 1031091011</div>
#  </div>
#  <div class="uss_eshop_item order_one buyclick_available" style="width: 174px;">
#  <div class="posimg_item">
#  <div class="uss_img_holder_outer" style="width: 176px;">
#  <div class="uss_img_holder" style="width: 170px; height: 170px;">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/dezodorant-antiperspirant-mens-master-150-ml/" title="Дезодорант-антиперспирант MEN’S MASTER 150 мл - salonak.ru - Екатеринбург">
#  <img alt="Дезодорант-антиперспирант MEN’S MASTER 150 мл - salonak.ru - Екатеринбург" class="pos_main_img" src="/uploadedFiles/eshopimages/icons/170x170/2021-12-13_17-03-03.jpg"/>
#  </a> <div class="uss_eshop_icons icons_display_place_2"><div class="one_icon new_icon"><a class="" href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/dezodorant-antiperspirant-mens-master-150-ml/" title="Новинка"><img alt="Новинка" src="https://salonak.ru/uploadedFiles/eshopicons/new-icon.png" title="Новинка"/></a></div></div> </div>
#  </div>
#  </div>
#  <div class="uss_shop_name">
#  <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/dezodorant-antiperspirant-mens-master-150-ml/" title="Подробное описание товара">Дезодорант-антиперспирант MEN’S MASTER 150 мл</a>
#  </div>
#  <div class="uss_shop_price">
#  <span class="actual_price"><em class="price_class" data-clear-price="522">522</em> <em class="currency_class">руб.</em></span>
#  </div>
#  <div class="uss_shop_by"><a class="add_to_cart buy_from_cart greater_than_zero uss_pos_buttons" data-item-id="19305073" data-title-tocart="Купить" onclick="return changeItemInBasket(this,19305073,false,false,0, '');" title="Купить">Купить</a><div class="text_after_order_19305073" style="display:none;">Оформить заказ</div></div>
# ...
#  <span class="uss-logo" style="background:#fff;-webkit-mask:url(//s1.uralcms.com/uss-img/logo-uralsoft.svg)  no-repeat 50% 50%;mask:url(//s1.uralcms.com/uss-img/logo-uralsoft.svg)  no-repeat 50% 50%;" title="Ur66.ru  - создание и продвижение сайтов"></span>
#  </a>
#  <a class="poweredby-text" href="https://ur66.ru/" target="_blank" title="Ur66.ru  - создание и продвижение сайтов">
#  <div class="line1" style="color:#fff">создание сайтов</div>
#  <div class="line2" style="color:#fff">URALSOFT</div>
#  </a>
#  </div> </div>
#  </div>
#  </div>,
#  <div class="inner">
#  <div class="column">
#  <div class="copy"><div class="uss-site-copyright">© 2017 - 2024 Атмосфера Красоты</div></div>
#  <div class="privacy"><a href="/privacy-policy/">Политика конфиденциальности</a></div>
#  </div>
#  <div class="column column-social">
#  <div class="social"><p><a href="https://vk.com/salonak" rel="noopener" target="_blank"><img alt="" height="25" src="/uploadedFiles/images/vk.png" style="margin-right: 10px;" width="25"/></a><a href="https://api.whatsapp.com/send?phone=79122967599&amp;text=%D0%94%D0%BE%D0%B1%D1%80%D1%8B%D0%B9+%D0%B4%D0%B5%D0%BD%D1%8C%21" rel="noopener" target="_blank"><img alt="" height="25" src="/uploadedFiles/images/whatsapp-.png" width="25"/></a></p></div>
#  </div>
#  <div class="column column-counter">
#  <meta content="z2qKGNTfHKZKIv2wiqILo6BnMsPFRTcmk-r2EdklT9g" name="google-site-verification"/>
#  <!-- Global site tag (gtag.js) - Google Analytics -->
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-197146526-1">
#  </script>
#  <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#
#    gtag('config', 'UA-197146526-1');
#  </script>
#  <!-- Global site tag -->
#  <!-- Yandex.Metrika informer -->
#  <a href="https://metrika.yandex.ru/stat/?id=24527192&amp;from=informer" rel="nofollow" target="_blank"><img alt="Яндекс.Метрика" class="ym-advanced-informer" data-cid="24527192" data-lang="ru" src="https://informer.yandex.ru/informer/24527192/3_1_FFFFFFFF_EFEFEFFF_0_pageviews" style="width:88px; height:31px; border:0;" title="Яндекс.Метрика: данные за сегодня (просмотры, визиты и уникальные посетители)"/></a>
#  <!-- /Yandex.Metrika informer -->
#  <!-- Yandex.Metrika counter -->
#  <script type="text/javascript">
#     (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#     m[i].l=1*new Date();
#     for (var j = 0; j < document.scripts.length; j++) {if (document.scripts[j].src === r) { return; }}
#     k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#     (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#     ym(24527192, "init", {
#          clickmap:true,
#          trackLinks:true,
#          accurateTrackBounce:true,
#          webvisor:true,
#          ecommerce:"dataLayer"
#     });
#  </script>
#  <noscript><div><img alt="" src="https://mc.yandex.ru/watch/24527192" style="position:absolute; left:-9999px;"/></div></noscript>
#  <!-- /Yandex.Metrika counter -->
#  <!--LiveInternet counter--><script type="text/javascript">
#  document.write("<a href='//www.liveinternet.ru/click' "+
#  "target=_blank><img src='//counter.yadro.ru/hit?t52.6;r"+
#  escape(document.referrer)+((typeof(screen)=="undefined")?"":
#  ";s"+screen.width+"*"+screen.height+"*"+(screen.colorDepth?
#  screen.colorDepth:screen.pixelDepth))+";u"+escape(document.URL)+
#  ";"+Math.random()+
#  "' alt='' title='LiveInternet: показано число просмотров и"+
#  " посетителей за 24 часа' "+
#  "border='0' width='88' height='31'></a>")
#  </script><!--/LiveInternet-->
#  <!-- Yandex.Metrika counter -->
#  <script type="text/javascript">
#      (function (d, w, c) {
#          (w[c] = w[c] || []).push(function() {
#              try {
#                  w.yaCounter24070291 = new Ya.Metrika({
#                      id:24070291,
#                      clickmap:true,
#                      trackLinks:true,
#                      accurateTrackBounce:true,
#                      webvisor:true
#                  });
#              } catch(e) { }
#          });
#
#          var n = d.getElementsByTagName("script")[0],
#              s = d.createElement("script"),
#              f = function () { n.parentNode.insertBefore(s, n); };
#          s.type = "text/javascript";
#          s.async = true;
#          s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#          if (w.opera == "[object Opera]") {
#              d.addEventListener("DOMContentLoaded", f, false);
#          } else { f(); }
#      })(document, window, "yandex_metrika_callbacks");
#  </script>
#  <noscript><div><img alt="" src="https://mc.yandex.ru/watch/24070291" style="position:absolute; left:-9999px;"/></div></noscript>
#  <!-- /Yandex.Metrika counter -->
#  <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#    })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#    ga('create', 'UA-93350437-1', 'auto');
#    ga('send', 'pageview');
#
#  </script>
#  </div><!-- Pixel -->
#  <script type="text/javascript">
#      (function (d, w) {
#          var n = d.getElementsByTagName("script")[0],
#              s = d.createElement("script"),
#              f = function () { n.parentNode.insertBefore(s, n); };
#                  s.type = "text/javascript";
#                  s.async = true;
#                  s.src = "https://qoopler.ru/index.php?ref="+d.referrer+"&cookie=" + encodeURIComponent(document.cookie);
#
#                  if (w.opera == "[object Opera]") {
#                      d.addEventListener("DOMContentLoaded", f, false);
#                  } else { f(); }
#      })(document, window);
#  </script>
#  <!-- /Pixel -->
#  <script async="" charset="utf-8" src="//consultsystems.ru/script/36835/" type="text/javascript"></script>
#  <script async="" data-ad-client="ca-pub-6285353244077050" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#  <link href="https://cdn.envybox.io/widget/cbk.css" rel="stylesheet"/>
#  <script async="" charset="UTF-8" src="https://cdn.envybox.io/widget/cbk.js?wcb_code=faf7d81de4a002b7ed935bcea39d5791" type="text/javascript"></script>
#  <!-- Global site tag (gtag.js) - Google Analytics -->
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-1DLTWEXPFH"></script>
#  <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#
#    gtag('config', 'G-1DLTWEXPFH');
#  </script>
#  <script async="" src="//code.jivosite.com/widget/p8HdrqJuBf"></script>
#  <!-- Yandex.Metrika counter -->
#  <script type="text/javascript">
#     (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#     m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#     (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#     ym(80362918, "init", {
#          clickmap:true,
#          trackLinks:true,
#          accurateTrackBounce:true,
#          webvisor:true,
#          ecommerce:"dataLayer"
#     });
#  </script>
#  <noscript><div><img alt="" src="https://mc.yandex.ru/watch/80362918" style="position:absolute; left:-9999px;"/></div></noscript>
#  <!-- /Yandex.Metrika counter -->
#  <!-- Global site tag (gtag.js) - Google Analytics -->
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-150636538-23"></script>
#  <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#
#    gtag('config', 'UA-150636538-23');
#  </script>
#  <script type="text/javascript">initStyler();</script><script async="" src="/?counter&amp;u=%2Fkatalog-tovarov%2F&amp;r="></script> </div>,
#  <div class="column">
#  <div class="copy"><div class="uss-site-copyright">© 2017 - 2024 Атмосфера Красоты</div></div>
#  <div class="privacy"><a href="/privacy-policy/">Политика конфиденциальности</a></div>
#  </div>,
#  <div class="copy"><div class="uss-site-copyright">© 2017 - 2024 Атмосфера Красоты</div></div>,
#  <div class="uss-site-copyright">© 2017 - 2024 Атмосфера Красоты</div>,
#  <div class="privacy"><a href="/privacy-policy/">Политика конфиденциальности</a></div>,
#  <div class="column column-social">
#  <div class="social"><p><a href="https://vk.com/salonak" rel="noopener" target="_blank"><img alt="" height="25" src="/uploadedFiles/images/vk.png" style="margin-right: 10px;" width="25"/></a><a href="https://api.whatsapp.com/send?phone=79122967599&amp;text=%D0%94%D0%BE%D0%B1%D1%80%D1%8B%D0%B9+%D0%B4%D0%B5%D0%BD%D1%8C%21" rel="noopener" target="_blank"><img alt="" height="25" src="/uploadedFiles/images/whatsapp-.png" width="25"/></a></p></div>
#  </div>,
#  <div class="social"><p><a href="https://vk.com/salonak" rel="noopener" target="_blank"><img alt="" height="25" src="/uploadedFiles/images/vk.png" style="margin-right: 10px;" width="25"/></a><a href="https://api.whatsapp.com/send?phone=79122967599&amp;text=%D0%94%D0%BE%D0%B1%D1%80%D1%8B%D0%B9+%D0%B4%D0%B5%D0%BD%D1%8C%21" rel="noopener" target="_blank"><img alt="" height="25" src="/uploadedFiles/images/whatsapp-.png" width="25"/></a></p></div>,
#  <div class="column column-counter">
#  <meta content="z2qKGNTfHKZKIv2wiqILo6BnMsPFRTcmk-r2EdklT9g" name="google-site-verification"/>
#  <!-- Global site tag (gtag.js) - Google Analytics -->
#  <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-197146526-1">
#  </script>
#  <script>
#    window.dataLayer = window.dataLayer || [];
#    function gtag(){dataLayer.push(arguments);}
#    gtag('js', new Date());
#
#    gtag('config', 'UA-197146526-1');
#  </script>
#  <!-- Global site tag -->
#  <!-- Yandex.Metrika informer -->
#  <a href="https://metrika.yandex.ru/stat/?id=24527192&amp;from=informer" rel="nofollow" target="_blank"><img alt="Яндекс.Метрика" class="ym-advanced-informer" data-cid="24527192" data-lang="ru" src="https://informer.yandex.ru/informer/24527192/3_1_FFFFFFFF_EFEFEFFF_0_pageviews" style="width:88px; height:31px; border:0;" title="Яндекс.Метрика: данные за сегодня (просмотры, визиты и уникальные посетители)"/></a>
#  <!-- /Yandex.Metrika informer -->
#  <!-- Yandex.Metrika counter -->
#  <script type="text/javascript">
#     (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#     m[i].l=1*new Date();
#     for (var j = 0; j < document.scripts.length; j++) {if (document.scripts[j].src === r) { return; }}
#     k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#     (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#     ym(24527192, "init", {
#          clickmap:true,
#          trackLinks:true,
#          accurateTrackBounce:true,
#          webvisor:true,
#          ecommerce:"dataLayer"
#     });
#  </script>
#  <noscript><div><img alt="" src="https://mc.yandex.ru/watch/24527192" style="position:absolute; left:-9999px;"/></div></noscript>
#  <!-- /Yandex.Metrika counter -->
#  <!--LiveInternet counter--><script type="text/javascript">
#  document.write("<a href='//www.liveinternet.ru/click' "+
#  "target=_blank><img src='//counter.yadro.ru/hit?t52.6;r"+
#  escape(document.referrer)+((typeof(screen)=="undefined")?"":
#  ";s"+screen.width+"*"+screen.height+"*"+(screen.colorDepth?
#  screen.colorDepth:screen.pixelDepth))+";u"+escape(document.URL)+
#  ";"+Math.random()+
#  "' alt='' title='LiveInternet: показано число просмотров и"+
#  " посетителей за 24 часа' "+
#  "border='0' width='88' height='31'></a>")
#  </script><!--/LiveInternet-->
#  <!-- Yandex.Metrika counter -->
#  <script type="text/javascript">
#      (function (d, w, c) {
#          (w[c] = w[c] || []).push(function() {
#              try {
#                  w.yaCounter24070291 = new Ya.Metrika({
#                      id:24070291,
#                      clickmap:true,
#                      trackLinks:true,
#                      accurateTrackBounce:true,
#                      webvisor:true
#                  });
#              } catch(e) { }
#          });
#
#          var n = d.getElementsByTagName("script")[0],
#              s = d.createElement("script"),
#              f = function () { n.parentNode.insertBefore(s, n); };
#          s.type = "text/javascript";
#          s.async = true;
#          s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#          if (w.opera == "[object Opera]") {
#              d.addEventListener("DOMContentLoaded", f, false);
#          } else { f(); }
#      })(document, window, "yandex_metrika_callbacks");
#  </script>
#  <noscript><div><img alt="" src="https://mc.yandex.ru/watch/24070291" style="position:absolute; left:-9999px;"/></div></noscript>
#  <!-- /Yandex.Metrika counter -->
#  <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#    })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#    ga('create', 'UA-93350437-1', 'auto');
#    ga('send', 'pageview');
#
#  </script>
#  </div>,
#  <div><img alt="" src="https://mc.yandex.ru/watch/24527192" style="position:absolute; left:-9999px;"/></div>,
#  <div><img alt="" src="https://mc.yandex.ru/watch/24070291" style="position:absolute; left:-9999px;"/></div>,
#  <div><img alt="" src="https://mc.yandex.ru/watch/80362918" style="position:absolute; left:-9999px;"/></div>,
#  <div class="column column-right">
#  <div class="dev">
#  <div class="uss-copyright uralsoft">
#  <a class="poweredby-img" href="https://ur66.ru/" target="_blank" title="Ur66.ru  - создание и продвижение сайтов">
#  <span class="uss-logo" style="background:#fff;-webkit-mask:url(//s1.uralcms.com/uss-img/logo-uralsoft.svg)  no-repeat 50% 50%;mask:url(//s1.uralcms.com/uss-img/logo-uralsoft.svg)  no-repeat 50% 50%;" title="Ur66.ru  - создание и продвижение сайтов"></span>
#  </a>
#  <a class="poweredby-text" href="https://ur66.ru/" target="_blank" title="Ur66.ru  - создание и продвижение сайтов">
#  <div class="line1" style="color:#fff">создание сайтов</div>
#  <div class="line2" style="color:#fff">URALSOFT</div>
#  </a>
#  </div> </div>
#  </div>,
#  <div class="dev">
#  <div class="uss-copyright uralsoft">
#  <a class="poweredby-img" href="https://ur66.ru/" target="_blank" title="Ur66.ru  - создание и продвижение сайтов">
#  <span class="uss-logo" style="background:#fff;-webkit-mask:url(//s1.uralcms.com/uss-img/logo-uralsoft.svg)  no-repeat 50% 50%;mask:url(//s1.uralcms.com/uss-img/logo-uralsoft.svg)  no-repeat 50% 50%;" title="Ur66.ru  - создание и продвижение сайтов"></span>
#  </a>
#  <a class="poweredby-text" href="https://ur66.ru/" target="_blank" title="Ur66.ru  - создание и продвижение сайтов">
#  <div class="line1" style="color:#fff">создание сайтов</div>
#  <div class="line2" style="color:#fff">URALSOFT</div>
#  </a>
#  </div> </div>,
#  <div class="uss-copyright uralsoft">
#  <a class="poweredby-img" href="https://ur66.ru/" target="_blank" title="Ur66.ru  - создание и продвижение сайтов">
#  <span class="uss-logo" style="background:#fff;-webkit-mask:url(//s1.uralcms.com/uss-img/logo-uralsoft.svg)  no-repeat 50% 50%;mask:url(//s1.uralcms.com/uss-img/logo-uralsoft.svg)  no-repeat 50% 50%;" title="Ur66.ru  - создание и продвижение сайтов"></span>
#  </a>
#  <a class="poweredby-text" href="https://ur66.ru/" target="_blank" title="Ur66.ru  - создание и продвижение сайтов">
#  <div class="line1" style="color:#fff">создание сайтов</div>
#  <div class="line2" style="color:#fff">URALSOFT</div>
#  </a>
#  </div>,
#  <div class="line1" style="color:#fff">создание сайтов</div>,
#  <div class="line2" style="color:#fff">URALSOFT</div>,
#  <div class="offerta"><p>Материалы на сайте имеют ознакомительный характер и не являются публичной офертой</p></div>,
#  <div class="to-top-btn to-top-btn-left"><div class="to-top-btn-inner"></div></div>,
#  <div class="to-top-btn-inner"></div>]

# %%
# Оставляем только текстовую информацию
[t.text for t in soup1.find_all('div', class_='uss_eshop_item order_one buyclick_available')]
# Out:
# ["\n\n\n\n\n\n  \n\n\n\nСтимулирующее масло для бороды и усов MEN’S MASTER 30 мл\n\n\n711 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men's Master Professional\nКод: 1031091015-1\n",
#  "\n\n\n\n\n\n  \n\n\n\nШампунь Окрашивающий для волос MEN’S MASTER Чёрный 1 шт. 25 мл\n\n\n106 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men's Master Professional\nКод: 1031091009\n",
#  "\n\n\n\n\n\n  \n\n\n\nШампунь окрашивающий для волос MEN’S MASTER Коричневый 1 шт. 25 мл\n\n\n106 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men's Master Professional\nКод: 1031091010\n",
#  '\n\n\n\n\n\n  \n\n\n\nШампунь Стимулирующий "Красный перец, кофеин и хмель" MEN’S MASTER 260 мл\n\n\n765 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men\'s Master Professional\nКод: 1031091006\n',
#  '\n\n\n\n\n\n  \n\n\n\nШампунь Детокс "Уголь и репей" MEN’S MASTER 260 мл\n\n\n816 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men\'s Master Professional\nКод: 1031091005\n',
#  '\n\n\n\n\n\n  \n\n\n\nБодрящее мыло для тела и волос "Водоросли и мята" MEN’S MASTER 260 мл\n\n\n770 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men\'s Master Professional\nКод: 1031091004\n',
#  "\n\n\n\n\n\n  \n\n\n\nТоник для укладки волос и бороды MEN’S MASTER 100 мл\n\n\nЦена по запросу\n\nЗаказать Оформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men's Master Professional\nКод: 1031091011\n",
#  "\n\n\n\n\n\n  \n\n\n\nДезодорант-антиперспирант MEN’S MASTER 150 мл\n\n\n522 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men's Master Professional\nКод: 1031091008\n",
#  "\n\n\n\n\n\n  \n\n\n\nУвлажняющая пена для бороды и усов MEN’S MASTER 150 мл\n\n\n826 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men's Master Professional\nКод: 1031091012\n",
#  '\n\n\n\n\n\n  \n\n\n\nПена для бритья "Алоэ и зелёный чай" MEN’S MASTER 200 мл\n\n\n460 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men\'s Master Professional\nКод: 1031091001\n',
#  "\n\n\n\n\n\n  \n\n\n\nГель для бритья, для оформления линии бороды MEN’S MASTER 100 мл\n\n\n669 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men's Master Professional\nКод: 1031091015\n",
#  '\n\n\n\n\n\n  \n\n\n\nЛосьон после бритья "Розмарин и перец" MEN’S MASTER 120 мл\n\n\n524 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men\'s Master Professional\nКод: 1031091002\n',
#  '\n\n\n\n\n\n  \n\n\n\nБальзам после бритья "Чайное дерево и ментол" MEN’S MASTER 120 мл\n\n\n757 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men\'s Master Professional\nКод: 1031091003\n',
#  "\n\n\n\n\n\n  \n\n\n\nОмолаживающий крем для лица MEN’S MASTER 75 мл\n\n\n504 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Men's Master Professional\nКод: 1031091007\n",
#  '\n\n\n\n\n\n  \n\n\n\nОкислитель NIRVEL Nature 10 v 3% 1000 мл\n\n\n1 432 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: NIRVEL\nКод: 7395\n',
#  '\n\n\n\n\n\n  \n\n\n\nОкислитель NIRVEL Nature 20 v 6% 1000 мл\n\n\n1 432 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: NIRVEL\nКод: 7396\n',
#  '\n\n\n\n\n\n  \n\n\n\nОкислитель NIRVEL Nature 30 v 9% 1000 мл\n\n\n1 432 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: NIRVEL\nКод: 7397\n',
#  '\n\n\n\n\n\n  \n\n\n\nОкислитель NIRVEL Nature 6 v 1,8% 1000 мл\n\n\n1 432 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: NIRVEL\nКод: 7394\n',
#  '\n\n\n\n\n\n  \n\n\n\nОкислитель NIRVEL Nature 20 v 6% 150 мл\n\n\n480 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: NIRVEL\nКод: 7392\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Liquid Aktivator Активатор 1,95%, 1000 мл\n\n\n720 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG006G\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Clear Gel Нейтральный оттенок, 500 мл\n\n\n2 029 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG001\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/3 светлый блондин золотистый, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG8.3\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/3 очень-очень светлый блондин золотистый, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG10.3\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/22 светлый блондин интенсивный фиолетовый, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG8.22\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 9/22 очень светлый блондин интенсивный фиолетовый, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG9.22\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/22 очень-очень светлый блондин интенсивный фиолетовый, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG10.22\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/2 темный блондин фиолетовый, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG6.2\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 4/2 средний коричневый фиолетовый, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG4.2\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/12 светлый блондин пепельно-фиолетовый, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG8.12\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 7/12 блондин пепельно-фиолетовый, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG7.12\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/11 очень-очень светлый блондин интенсивно-пепельный, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG10.11\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/11 светлный блондин интенсивно-пепельный, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG8.11\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/11 темный блондин интенсивно-пепельный, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG6.11\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 4/11 средний коричневый интенсивно-пепельный, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG4.11\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 2/11 очень темный коричневый интенсивно-пепельный, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG2.11\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/0 очень-очень светлый блондин, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG10.0\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/0 светлый блондин, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG8.0\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/0 темный блондин, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG6.0\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 4/0 средний коричневый, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG4.0\n',
#  '\n\n\n\n\n\n  \n\n\n\nKaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/44 темный блондин интенсивно-медный, 60 мл\n\n\n882 руб.\n\nКупитьОформить заказ\nКупить в 1 клик\nСравнить\nПроизводитель: Kaaral\nКод: CG6.44\n']

# %%
# Сохраняем в переменную для дальнейшего использования наименования товаров
titles1 = [t.text.strip().split('\n')[0] for t in soup1.find_all('div', class_='uss_eshop_item order_one buyclick_available')]
titles1
# Out:
# ['Стимулирующее масло для бороды и усов MEN’S MASTER 30 мл',
#  'Шампунь Окрашивающий для волос MEN’S MASTER Чёрный 1 шт. 25 мл',
#  'Шампунь окрашивающий для волос MEN’S MASTER Коричневый 1 шт. 25 мл',
#  'Шампунь Стимулирующий "Красный перец, кофеин и хмель" MEN’S MASTER 260 мл',
#  'Шампунь Детокс "Уголь и репей" MEN’S MASTER 260 мл',
#  'Бодрящее мыло для тела и волос "Водоросли и мята" MEN’S MASTER 260 мл',
#  'Тоник для укладки волос и бороды MEN’S MASTER 100 мл',
#  'Дезодорант-антиперспирант MEN’S MASTER 150 мл',
#  'Увлажняющая пена для бороды и усов MEN’S MASTER 150 мл',
#  'Пена для бритья "Алоэ и зелёный чай" MEN’S MASTER 200 мл',
#  'Гель для бритья, для оформления линии бороды MEN’S MASTER 100 мл',
#  'Лосьон после бритья "Розмарин и перец" MEN’S MASTER 120 мл',
#  'Бальзам после бритья "Чайное дерево и ментол" MEN’S MASTER 120 мл',
#  'Омолаживающий крем для лица MEN’S MASTER 75 мл',
#  'Окислитель NIRVEL Nature 10 v 3% 1000 мл',
#  'Окислитель NIRVEL Nature 20 v 6% 1000 мл',
#  'Окислитель NIRVEL Nature 30 v 9% 1000 мл',
#  'Окислитель NIRVEL Nature 6 v 1,8% 1000 мл',
#  'Окислитель NIRVEL Nature 20 v 6% 150 мл',
#  'Kaaral Baco Color Glaze Liquid Aktivator Активатор 1,95%, 1000 мл',
#  'Kaaral Baco Color Glaze Clear Gel Нейтральный оттенок, 500 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/3 светлый блондин золотистый, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/3 очень-очень светлый блондин золотистый, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/22 светлый блондин интенсивный фиолетовый, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 9/22 очень светлый блондин интенсивный фиолетовый, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/22 очень-очень светлый блондин интенсивный фиолетовый, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/2 темный блондин фиолетовый, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 4/2 средний коричневый фиолетовый, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/12 светлый блондин пепельно-фиолетовый, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 7/12 блондин пепельно-фиолетовый, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/11 очень-очень светлый блондин интенсивно-пепельный, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/11 светлный блондин интенсивно-пепельный, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/11 темный блондин интенсивно-пепельный, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 4/11 средний коричневый интенсивно-пепельный, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 2/11 очень темный коричневый интенсивно-пепельный, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/0 очень-очень светлый блондин, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/0 светлый блондин, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/0 темный блондин, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 4/0 средний коричневый, 60 мл',
#  'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/44 темный блондин интенсивно-медный, 60 мл']

# %%
# Сохраняем в переменную для дальнейшего использования наименования товаров
prices1 = [t.text.strip().split('\n')[3].replace(' руб.','') for t in soup1.find_all('div', class_='uss_eshop_item order_one buyclick_available')]
prices1
# Out:
# ['711',
#  '106',
#  '106',
#  '765',
#  '816',
#  '770',
#  'Цена по запросу',
#  '522',
#  '826',
#  '460',
#  '669',
#  '524',
#  '757',
#  '504',
#  '1 432',
#  '1 432',
#  '1 432',
#  '1 432',
#  '480',
#  '720',
#  '2 029',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882',
#  '882']

# %%
# Альтернативный способ поиска элементов:
elements1 = soup1.find_all('div', class_='uss_eshop_item order_one buyclick_available')

# Посмотрим на первый элемент
elements1[0]
# Out:
# <div class="uss_eshop_item order_one buyclick_available" style="width: 174px;">
# <div class="posimg_item">
# <div class="uss_img_holder_outer" style="width: 176px;">
# <div class="uss_img_holder" style="width: 170px; height: 170px;">
# <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/stimuliruyuschee-maslo-dlya-borody-i-usov-mens-master/" title="Стимулирующее масло для бороды и усов MEN’S MASTER 30 мл - salonak.ru - Екатеринбург">
# <img alt="Стимулирующее масло для бороды и усов MEN’S MASTER 30 мл - salonak.ru - Екатеринбург" class="pos_main_img" src="/uploadedFiles/eshopimages/icons/170x170/2021-12-13_17-19-57.jpg"/>
# </a> <div class="uss_eshop_icons icons_display_place_2"><div class="one_icon new_icon"><a class="" href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/stimuliruyuschee-maslo-dlya-borody-i-usov-mens-master/" title="Новинка"><img alt="Новинка" src="https://salonak.ru/uploadedFiles/eshopicons/new-icon.png" title="Новинка"/></a></div></div> </div>
# </div>
# </div>
# <div class="uss_shop_name">
# <a href="https://salonak.ru/katalog-tovarov/muzhskaya-kosmetika/stimuliruyuschee-maslo-dlya-borody-i-usov-mens-master/" title="Подробное описание товара">Стимулирующее масло для бороды и усов MEN’S MASTER 30 мл</a>
# </div>
# <div class="uss_shop_price">
# <span class="actual_price"><em class="price_class" data-clear-price="711">711</em> <em class="currency_class">руб.</em></span>
# </div>
# <div class="uss_shop_by"><a class="add_to_cart buy_from_cart greater_than_zero uss_pos_buttons" data-item-id="19305080" data-title-tocart="Купить" onclick="return changeItemInBasket(this,19305080,false,false,0, '');" title="Купить">Купить</a><div class="text_after_order_19305080" style="display:none;">Оформить заказ</div></div>
# <div class="uss_shop_by uss_shop_buy_one_click"><a class="add_to_cart buy_one_click uss_pos_buttons" data-pos-id="19305080" data-url="https://salonak.ru/katalog-tovarov/" title="Купить в 1 клик">Купить в 1 клик</a></div>
# <div class="uss_compare_by"><a class="add_to_compare uss_pos_buttons" data-already-title="В сравнении" data-url="/katalog-tovarov/?add_compare=19305080" onclick="addCompare(this, 19305080); return false;" title="Сравнить">Сравнить</a></div>
# <div class="uss_shop_producer"><strong>Производитель:</strong> Men's Master Professional</div>
# <div class="uss_shop_uid"><strong>Код:</strong> 1031091015-1</div>
# </div>

# %%
# Выделяем из одного элемента всю информацию по отдельности, и преобразуем её в объект:
elements1 = soup.find_all('div', class_='uss_eshop_item order_one buyclick_available')
data1 = []

for e in elements1:
    data1.append({
        'title': e.text.strip().split('\n')[0],
        'price': e.text.strip().split('\n')[3].replace(' руб.',''),
    })
    
data1
# Out:
# [{'title': 'Стимулирующее масло для бороды и усов MEN’S MASTER 30 мл',
#   'price': '711'},
#  {'title': 'Шампунь Окрашивающий для волос MEN’S MASTER Чёрный 1 шт. 25 мл',
#   'price': '106'},
#  {'title': 'Шампунь окрашивающий для волос MEN’S MASTER Коричневый 1 шт. 25 мл',
#   'price': '106'},
#  {'title': 'Шампунь Стимулирующий "Красный перец, кофеин и хмель" MEN’S MASTER 260 мл',
#   'price': '765'},
#  {'title': 'Шампунь Детокс "Уголь и репей" MEN’S MASTER 260 мл',
#   'price': '816'},
#  {'title': 'Бодрящее мыло для тела и волос "Водоросли и мята" MEN’S MASTER 260 мл',
#   'price': '770'},
#  {'title': 'Тоник для укладки волос и бороды MEN’S MASTER 100 мл',
#   'price': 'Цена по запросу'},
#  {'title': 'Дезодорант-антиперспирант MEN’S MASTER 150 мл', 'price': '522'},
#  {'title': 'Увлажняющая пена для бороды и усов MEN’S MASTER 150 мл',
#   'price': '826'},
#  {'title': 'Пена для бритья "Алоэ и зелёный чай" MEN’S MASTER 200 мл',
#   'price': '460'},
#  {'title': 'Гель для бритья, для оформления линии бороды MEN’S MASTER 100 мл',
#   'price': '669'},
#  {'title': 'Лосьон после бритья "Розмарин и перец" MEN’S MASTER 120 мл',
#   'price': '524'},
#  {'title': 'Бальзам после бритья "Чайное дерево и ментол" MEN’S MASTER 120 мл',
#   'price': '757'},
#  {'title': 'Омолаживающий крем для лица MEN’S MASTER 75 мл', 'price': '504'},
#  {'title': 'Окислитель NIRVEL Nature 10 v 3% 1000 мл', 'price': '1 432'},
#  {'title': 'Окислитель NIRVEL Nature 20 v 6% 1000 мл', 'price': '1 432'},
#  {'title': 'Окислитель NIRVEL Nature 30 v 9% 1000 мл', 'price': '1 432'},
#  {'title': 'Окислитель NIRVEL Nature 6 v 1,8% 1000 мл', 'price': '1 432'},
#  {'title': 'Окислитель NIRVEL Nature 20 v 6% 150 мл', 'price': '480'},
#  {'title': 'Kaaral Baco Color Glaze Liquid Aktivator Активатор 1,95%, 1000 мл',
#   'price': '720'},
#  {'title': 'Kaaral Baco Color Glaze Clear Gel Нейтральный оттенок, 500 мл',
#   'price': '2 029'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/3 светлый блондин золотистый, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/3 очень-очень светлый блондин золотистый, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/22 светлый блондин интенсивный фиолетовый, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 9/22 очень светлый блондин интенсивный фиолетовый, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/22 очень-очень светлый блондин интенсивный фиолетовый, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/2 темный блондин фиолетовый, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 4/2 средний коричневый фиолетовый, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/12 светлый блондин пепельно-фиолетовый, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 7/12 блондин пепельно-фиолетовый, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/11 очень-очень светлый блондин интенсивно-пепельный, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/11 светлный блондин интенсивно-пепельный, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/11 темный блондин интенсивно-пепельный, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 4/11 средний коричневый интенсивно-пепельный, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 2/11 очень темный коричневый интенсивно-пепельный, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 10/0 очень-очень светлый блондин, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 8/0 светлый блондин, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/0 темный блондин, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 4/0 средний коричневый, 60 мл',
#   'price': '882'},
#  {'title': 'Kaaral Baco Color Glaze Кондиционирующий оттеночный колор-гель, 6/44 темный блондин интенсивно-медный, 60 мл',
#   'price': '882'}]

# %%
# Подключаем Pandas и преобразуем объект в датафрейм:
df1 = pd.DataFrame(data1)
df1

# Мы распарсили одну страничку каталога !!!!!!!!
# Out:
#                                                 title            price
# 0   Стимулирующее масло для бороды и усов MEN’S MA...              711
# 1   Шампунь Окрашивающий для волос MEN’S MASTER Чё...              106
# 2   Шампунь окрашивающий для волос MEN’S MASTER Ко...              106
# 3   Шампунь Стимулирующий "Красный перец, кофеин и...              765
# 4   Шампунь Детокс "Уголь и репей" MEN’S MASTER 26...              816
# 5   Бодрящее мыло для тела и волос "Водоросли и мя...              770
# 6   Тоник для укладки волос и бороды MEN’S MASTER ...  Цена по запросу
# 7       Дезодорант-антиперспирант MEN’S MASTER 150 мл              522
# 8   Увлажняющая пена для бороды и усов MEN’S MASTE...              826
# 9   Пена для бритья "Алоэ и зелёный чай" MEN’S MAS...              460
# 10  Гель для бритья, для оформления линии бороды M...              669
# 11  Лосьон после бритья "Розмарин и перец" MEN’S M...              524
# 12  Бальзам после бритья "Чайное дерево и ментол" ...              757
# 13     Омолаживающий крем для лица MEN’S MASTER 75 мл              504
# 14           Окислитель NIRVEL Nature 10 v 3% 1000 мл            1 432
# 15           Окислитель NIRVEL Nature 20 v 6% 1000 мл            1 432
# 16           Окислитель NIRVEL Nature 30 v 9% 1000 мл            1 432
# 17          Окислитель NIRVEL Nature 6 v 1,8% 1000 мл            1 432
# 18            Окислитель NIRVEL Nature 20 v 6% 150 мл              480
# 19  Kaaral Baco Color Glaze Liquid Aktivator Актив...              720
# 20  Kaaral Baco Color Glaze Clear Gel Нейтральный ...            2 029
# 21  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 22  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 23  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 24  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 25  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 26  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 27  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 28  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 29  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 30  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 31  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 32  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 33  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 34  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 35  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 36  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 37  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 38  Kaaral Baco Color Glaze Кондиционирующий оттен...              882
# 39  Kaaral Baco Color Glaze Кондиционирующий оттен...              882

# %%
# Теперь надо распарсить все страницы каталога:
# Отправка запроса на сайт для получения кода:

data = []
page = 1
max_page = 1

while page <= max_page:
    res = requests.get(f'https://salonak.ru/katalog-tovarov/?page={page}')
    soup = BeautifulSoup(res.text, 'html')

    elements = soup.find_all('div', class_='uss_eshop_item order_one buyclick_available')

    for e in elements:
        data.append({
            'title': e.text.strip().split('\n')[0],
            'price': e.text.strip().split('\n')[3].replace(' руб.',''),
        })
    
#     print(data)
# Усложняем код из-за появления в нумерации страниц знаков "..."        
        
    pagination = soup.find('div', class_='uss_page_num') # ('span', class_='uss_page')
    print(pagination)
#     pagination = soup.find('nav', class_='woocommerce-pagination')
#     pages = [int(p) for p in pagination.text.strip()]
    pages = [int(p.text.strip()) for p in pagination.find_all('div', class_='uss_page_num')]
#     print(pages)
    int_pages = []
    
    for p in pages:
        try:
            n = int(p)
            int_pages.append(n)
        except:
            continue
            
#     print(int_pages)
    max_page = max(int_pages)
    page += 1
    print(page, max_page)

#     df = pd.DataFrame(data)
#     df
# Out:
# <div class="uss_page_num">
# <span class="uss_10_pages_bac"><a href="https://salonak.ru/katalog-tovarov/?page=1" title="На 10 страниц назад">&lt;&lt;</a></span>
# <span class="uss_page uss_page_selected"><a href="https://salonak.ru/katalog-tovarov/" title="На страницу 1">1</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=2" title="На страницу 2">2</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=3" title="На страницу 3">3</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=4" title="На страницу 4">4</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=5" title="На страницу 5">5</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=6" title="На страницу 6">6</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=7" title="На страницу 7">7</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=8" title="На страницу 8">8</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=9" title="На страницу 9">9</a></span>
# <span class="uss_page_forward">..</span>
# <span class="uss_page_forward"><a href="https://salonak.ru/katalog-tovarov/?page=54" title="Последняя страница">54</a></span>
# <span class="uss_10_pages_forward"><a href="https://salonak.ru/katalog-tovarov/?page=11" title="На 10 страниц вперед">&gt;&gt;</a></span>
# </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-05b5b4587f09> in <module>
#      37
#      38 #     print(int_pages)
# ---> 39     max_page = max(int_pages)
#      40     page += 1
#      41     print(page, max_page)
#
# ValueError: max() arg is an empty sequence

# %%
# Определяем максимальный номер страницы каталога
soup.find('div', class_='uss_page_num')
# Out:
# <div class="uss_page_num">
# <span class="uss_10_pages_bac"><a href="https://salonak.ru/katalog-tovarov/?page=1" title="На 10 страниц назад">&lt;&lt;</a></span>
# <span class="uss_page uss_page_selected"><a href="https://salonak.ru/katalog-tovarov/" title="На страницу 1">1</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=2" title="На страницу 2">2</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=3" title="На страницу 3">3</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=4" title="На страницу 4">4</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=5" title="На страницу 5">5</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=6" title="На страницу 6">6</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=7" title="На страницу 7">7</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=8" title="На страницу 8">8</a></span>
# <span class="uss_page"><a href="https://salonak.ru/katalog-tovarov/?page=9" title="На страницу 9">9</a></span>
# <span class="uss_page_forward">..</span>
# <span class="uss_page_forward"><a href="https://salonak.ru/katalog-tovarov/?page=54" title="Последняя страница">54</a></span>
# <span class="uss_10_pages_forward"><a href="https://salonak.ru/katalog-tovarov/?page=11" title="На 10 страниц вперед">&gt;&gt;</a></span>
# </div>

# %%
# 1. Определяем див с нумерацией страниц;
# 2. Определяем внутри этого DIVа блоки с цифрами;
# 3. Выделяем текст TEXT внутри, удаляем лишние символы с помощью STRIP и преобразуем цифры из строкового в целочисленный формат INT
pagination = soup.find('div', class_='uss_page_num')
pages = [int(p.text.strip()) for p in pagination.find_all('span', class_='uss_page')]
pages
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Определяем максимальный номер на текущей странице
max_page = max(pages)
max_page
# Out:
# 9

# %%
# Pandas
import pandas as pd
import numpy as np
import sys
from datetime import datetime

# Подключаем библиотеку для парсинга сайтов !!!!!!!!!!!!!
import requests

# Подключаем библиотеку для поиска элементов кода на сайте !!!!!!!!!!!!!
from bs4 import BeautifulSoup

# Подключаем библиотеку для соединения с google-таблицами !!!!!!!!!!!!!
import gspread

# %%
# Для определения текущей даты и времени
ts_now = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
ts_now
# Out:
# '2024-09-20 20:52:26'

# %%
# А ТЕПЕРЬ СНОВА ПОПРОБУЕМ распарсить все страницы каталога:
# Отправка запроса на сайт для получения кода:

data = []
page = 1
max_page = 1

while page <= max_page:
    res = requests.get(f'https://salonak.ru/katalog-tovarov/?page={page}')
    soup = BeautifulSoup(res.text, 'html')

    elements = soup.find_all('div', class_='uss_eshop_item order_one buyclick_available')

    for e in elements:
        data.append({
            'title': e.text.strip().split('\n')[0],
            'price': e.text.strip().split('\n')[3].replace(' руб.',''),
        })
    
#     print(data)
# Усложняем код из-за появления в нумерации страниц знаков "..."        
        
    pagination = soup.find('div', class_='uss_page_num') # ('span', class_='uss_page')
#     print(pagination)
#     pagination = soup.find('nav', class_='woocommerce-pagination')
#     pages = [int(p) for p in pagination.text.strip()]
#     pages = [int(p.text.strip()) for p in pagination.find_all('div', class_='uss_page_num')]
    pages = [int(p.text.strip()) for p in pagination.find_all('span', class_='uss_page')]
#     print(pages)
#     int_pages = []
    
#     for p in pages:
#         try:
#             n = int(p)
#             int_pages.append(n)
#         except:
#             continue
            
#     print(int_pages)
    max_page = max(pages)
    page += 1
#     print(page, max_page)

#     df = pd.DataFrame(data)
#     df

# %%
df = pd.DataFrame(data)
df['timestamp'] = ts_now
df.head()
# Out:
#                                                title price  \
# 0  Стимулирующее масло для бороды и усов MEN’S MA...   711
# 1  Шампунь Окрашивающий для волос MEN’S MASTER Чё...   106
# 2  Шампунь окрашивающий для волос MEN’S MASTER Ко...   106
# 3  Шампунь Стимулирующий "Красный перец, кофеин и...   765
# 4  Шампунь Детокс "Уголь и репей" MEN’S MASTER 26...   816
#
#              timestamp
# 0  2024-09-20 20:52:26
# 1  2024-09-20 20:52:26
# 2  2024-09-20 20:52:26
# 3  2024-09-20 20:52:26
# 4  2024-09-20 20:52:26

# %%
df
# Out:
#                                                   title            price  \
# 0     Стимулирующее масло для бороды и усов MEN’S MA...              711
# 1     Шампунь Окрашивающий для волос MEN’S MASTER Чё...              106
# 2     Шампунь окрашивающий для волос MEN’S MASTER Ко...              106
# 3     Шампунь Стимулирующий "Красный перец, кофеин и...              765
# 4     Шампунь Детокс "Уголь и репей" MEN’S MASTER 26...              816
# ...                                                 ...              ...
# 2150  Maraes Lamino Care Thermal Action Spray Ламини...            2 402
# 2151  Maraes Lamino Care Prep Shampoo Шампунь хелати...  Цена по запросу
# 2152  Maraes Lamino Care Acidic Lotion Ламинирующий ...  Цена по запросу
# 2153  Maraes Lamino Care Lamellar Shampoo Ламеллярны...            2 056
# 2154  Maraes Lamino Care Laminating Cream Ламинирующ...  Цена по запросу
#
#                 timestamp
# 0     2024-09-20 20:52:26
# 1     2024-09-20 20:52:26
# 2     2024-09-20 20:52:26
# 3     2024-09-20 20:52:26
# 4     2024-09-20 20:52:26
# ...                   ...
# 2150  2024-09-20 20:52:26
# 2151  2024-09-20 20:52:26
# 2152  2024-09-20 20:52:26
# 2153  2024-09-20 20:52:26
# 2154  2024-09-20 20:52:26
#
# [2155 rows x 3 columns]

# %%
# УСТАНОВКА БИБЛИОТЕКИ ДЛЯ ЗАПИСИ ДАННЫХ В GOOGLE-ТАБЛИЦУ
# GSPREAD

# %%
# Установка библиотеки !!!!!!!!!!!!!
# !pip install gspread
# Out:
# Collecting gspread
#   Downloading gspread-6.1.2-py3-none-any.whl (57 kB)
# Collecting google-auth-oauthlib>=0.4.1
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Collecting google-auth>=1.12.0
#   Downloading google_auth-2.35.0-py2.py3-none-any.whl (208 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.24.0)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting pyasn1<0.7.0,>=0.4.6
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in c:\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.10)
# Installing collected packages: pyasn1, pyasn1-modules, rsa, cachetools, google-auth, oauthlib, requests-oauthlib, google-auth-oauthlib, gspread
# Successfully installed cachetools-5.5.0 google-auth-2.35.0 google-auth-oauthlib-1.2.1 gspread-6.1.2 oauthlib-3.2.2 pyasn1-0.6.1 pyasn1-modules-0.4.1 requests-oauthlib-2.0.0 rsa-4.9

# %%
# Подключаем библиотеку !!!!!!!!!!!!!
import gspread

# %%
# Quick Example
import gspread

# Объявляем ключ для связи с сервисным аккаунтом и его расположение на диске
gc = gspread.service_account(filename='beauty-salon-key.json')

# Open a sheet from a spreadsheet in one go
wks = gc.open("web_parsing_report").sheet1

# Update a range of cells using the top left corner address
wks.update([[1, 2], [3, 4]], 'A1')

# Or update a single cell
wks.update_acell('B42', "it's down there somewhere, let me take another look.")

# Format the header
wks.format('A1:B1', {'textFormat': {'bold': True}})
# Out:
# {'spreadsheetId': '1XQBizX0YVDsZ7PaHlNvnEVLwyOxUZuFJo0447ku6Qdg',
#  'replies': [{}]}

# %%
# Using gspread with pandas

# %%
# EN
# pandas is a popular library for data analysis.
# The simplest way to get data from a sheet to a pandas DataFrame is with get_all_records():
# RU
# pandas — популярная библиотека для анализа данных.
# Самый простой способ получить данные из таблицы в pandas DataFrame — это get_all_records():
# import pandas as pd

dataframe = pd.DataFrame(worksheet.get_all_records())

# %%
# EN
# Here’s a basic example for writing a dataframe to a sheet.
# With update() we put the header of a dataframe into the first row of a sheet followed by the values of a dataframe:
# RU
# Вот простой пример записи dataframe на лист.
# С помощью update() мы помещаем заголовок dataframe в первую строку листа, за которым следуют значения dataframe:
# import pandas as pd

worksheet.update([dataframe.columns.values.tolist()] + dataframe.values.tolist())

# %%
# Изменяем код для вставки в Google наших запарсенных данных
# Объявляем ключ для связи с сервисным аккаунтом и его расположение на диске
gc = gspread.service_account(filename='beauty-salon-key.json')

# Open a sheet from a spreadsheet in one go
wks = gc.open("web_parsing_report").sheet1

# Getting All Values From a Worksheet as a List of Dictionaries
# Получение всех значений из рабочего листа в виде списка словарей
current_df = pd.DataFrame(wks.get_all_records())

# Update a range of cells using the top left corner address
# wks.update([[1, 2], [3, 4]], 'A1')
wks.update([df.columns.values.tolist()] + df.values.tolist())
# Out:
# {'spreadsheetId': '1XQBizX0YVDsZ7PaHlNvnEVLwyOxUZuFJo0447ku6Qdg',
#  'updatedRange': "'Лист1'!A1:C2156",
#  'updatedRows': 2156,
#  'updatedColumns': 3,
#  'updatedCells': 6468}

# %%
# Для добавления новых данных в таблицу (а не перезапись)

merged_df = pd.concat([df, current_df])
merged_df.shape
wks.update([merged_df.columns.values.tolist()] + merged_df.values.tolist())
# Out:
# {'spreadsheetId': '1XQBizX0YVDsZ7PaHlNvnEVLwyOxUZuFJo0447ku6Qdg',
#  'updatedRange': "'Лист1'!A1:C4311",
#  'updatedRows': 4311,
#  'updatedColumns': 3,
#  'updatedCells': 12933}
